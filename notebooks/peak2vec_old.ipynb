# %% [markdown]
# # Set up the environment

# %% [markdown]
# ## Install packages

# %% [markdown]
# ## Import packages

# %%
import scanpy as sc
import muon as mu
import torch
import scipy as sp
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from muon import atac as ac
import pandas as pd

sns.set_theme(style="white")

# %% [markdown]
# ## Helping functions

# %% [markdown]
# ## Load data

# %%
adata = sc.read_h5ad("data/pbmc10k_eda.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 10126 × 264916
#     obs: 'cisTopic_nr_frag', 'cisTopic_log_nr_frag', 'cisTopic_nr_acc', 'cisTopic_log_nr_acc', 'sample_id', 'barcode_rank', 'total_fragments_count', 'log10_total_fragments_count', 'unique_fragments_count', 'log10_unique_fragments_count', 'total_fragments_in_peaks_count', 'log10_total_fragments_in_peaks_count', 'unique_fragments_in_peaks_count', 'log10_unique_fragments_in_peaks_count', 'fraction_of_fragments_in_peaks', 'duplication_count', 'duplication_ratio', 'nucleosome_signal', 'tss_enrichment', 'pdf_values_for_tss_enrichment', 'pdf_values_for_fraction_of_fragments_in_peaks', 'pdf_values_for_duplication_ratio', 'barcode', 'n_features_per_cell', 'total_fragment_counts', 'leiden'
#     var: 'Chromosome', 'Start', 'End', 'Width', 'cisTopic_nr_frag', 'cisTopic_log_nr_frag', 'cisTopic_nr_acc', 'cisTopic_log_nr_acc', 'n_cells_per_feature', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'leiden', 'leiden_colors', 'lsi', 'neighbors', 'umap'
#     obsm: 'X_lsi', 'X_umap'
#     varm: 'LSI'
#     layers: 'binary', 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata_peaks = sc.read_h5ad("data/pbmc10k_peaks_eda.h5ad")
adata_peaks
# Out:
# AnnData object with n_obs × n_vars = 264916 × 10126
#     obs: 'Chromosome', 'Start', 'End', 'Width', 'cisTopic_nr_frag', 'cisTopic_log_nr_frag', 'cisTopic_nr_acc', 'cisTopic_log_nr_acc', 'n_cells_per_feature', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'leiden'
#     var: 'cisTopic_nr_frag', 'cisTopic_log_nr_frag', 'cisTopic_nr_acc', 'cisTopic_log_nr_acc', 'sample_id', 'barcode_rank', 'total_fragments_count', 'log10_total_fragments_count', 'unique_fragments_count', 'log10_unique_fragments_count', 'total_fragments_in_peaks_count', 'log10_total_fragments_in_peaks_count', 'unique_fragments_in_peaks_count', 'log10_unique_fragments_in_peaks_count', 'fraction_of_fragments_in_peaks', 'duplication_count', 'duplication_ratio', 'nucleosome_signal', 'tss_enrichment', 'pdf_values_for_tss_enrichment', 'pdf_values_for_fraction_of_fragments_in_peaks', 'pdf_values_for_duplication_ratio', 'barcode', 'n_features_per_cell', 'total_fragment_counts', 'leiden'
#     uns: 'Chromosome_colors', 'leiden', 'leiden_colors', 'lsi', 'neighbors', 'umap'
#     obsm: 'LSI', 'X_umap'
#     varm: 'X_lsi', 'X_umap'
#     layers: 'binary', 'counts'
#     obsp: 'connectivities', 'distances'
#     varp: 'connectivities', 'distances'

# %% [markdown]
# # PEAK2VEC Model

# %% [markdown]
# ## Build a negative sampling and subsampling distributions

# %% [markdown]
# Let's visualise the subsampling probabilities

# %%
t = 1e-3
p = np.linspace(0, 0.1, 100)
keep_probability1 = np.minimum(1.0, np.sqrt(t / np.maximum(p, 1e-12)))
keep_probability2 = np.minimum(1.0, np.exp( np.maximum(p, 1e-12) / -t * 1e-1 ))
keep_probability3 = np.minimum(1.0, np.cbrt(t / np.maximum(p, 1e-12)))

plt.plot(p, keep_probability1, label=f"sqrt")
plt.plot(p, keep_probability2, label="exp")
plt.plot(p, keep_probability3, label="cbrt")
plt.legend()
plt.xlabel("Feature frequency")
plt.ylabel("Keep probability")
# Out:
# Text(0, 0.5, 'Keep probability')

# %%
# Negative sampling distribution
frequency = adata.var.cisTopic_nr_acc / adata.var.cisTopic_nr_acc.sum()
neg_probability = np.power(np.maximum(frequency, 1e-12), 0.75)
neg_probability = neg_probability / neg_probability.sum()

# Subsampling distribution
t = 5e-7
keep_probability = np.minimum(1.0, np.sqrt(t / np.maximum(frequency, 1e-12)))

# Add those to adata.var
adata.var["neg"] = neg_probability
adata.var["keep"] = keep_probability
adata.var["frequency"] = frequency

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 4))

sns.histplot(np.log10(frequency), ax=ax1)
ax1.set_xlabel("Log Frequency")
ax1.set_title("Feature Frequencies")

sns.histplot(np.log10(neg_probability), ax=ax2)
ax2.set_xlabel("Log Probability")
ax2.set_title("Negative Sampling Distribution")

sns.histplot(keep_probability, ax=ax3)
ax3.set_xlabel("Keep Probability")
ax3.set_title("Subsampling Distribution")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 8))
sns.violinplot(data=adata.var, x="frequency", y="Chromosome", log_scale=10, ax=ax1, inner=None)
sns.violinplot(data=adata.var, x="neg", y="Chromosome", log_scale=10, ax=ax2, inner=None)
# Out:
# <Axes: xlabel='neg', ylabel='Chromosome'>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 8))


sns.violinplot(data=adata.var, x="keep", y="Chromosome", ax=ax1, inner=None)
sns.barplot(data=adata.var, x="cisTopic_nr_acc", y="Chromosome", errorbar=None, estimator="sum", ax=ax2)
sns.countplot(data=adata.var, y="Chromosome", stat="proportion", ax=ax3)
# Out:
# <Axes: xlabel='proportion', ylabel='Chromosome'>

# %% [markdown]
# ## Dataset

# %%
import torch.nn as nn
from torch.utils.data import IterableDataset, DataLoader, get_worker_info
from collections import defaultdict

# %%
distance = np.linspace(0, 5e5, 1000)

plt.plot(distance, np.exp(-distance / 5e5), label=f"exp(-d / 5e5)")
plt.plot(distance, np.exp(-distance / 2e5), label="exp(-d / 1e5)")
plt.plot(distance, np.exp(-distance / 5e4), label="exp(-d / 5e4)")
plt.plot(distance, 1 / (1 + (distance / 5e4) ** 1.5), label="(1 / (1 + (d / 5e4)^1.5))")
plt.plot(distance, 1 / (1 + (distance / 1e5) ** 1.5), label="(1 / (1 + (d / 1e5)^1.5))")
plt.legend()
plt.xlabel("Distance")
plt.ylabel("Weight for cis-pair sampling")
# Out:
# Text(0, 0.5, 'Weight for cis-pair sampling')

# %%
class PeakDataset(IterableDataset):
    def __init__(self, adata, samples_per_epoch=10000, n_pairs=10, n_negative=20, seed=4, trans_fraction=0.2, cis_window=500000, same_chr_negative_prob=0.5):
        self.adata = adata
        self.samples_per_epoch = samples_per_epoch
        self.n_pairs = n_pairs
        self.n_negative = n_negative
        self.seed = seed
        self.trans_fraction = trans_fraction
        self.cis_window = cis_window
        self.same_chr_negative_prob = same_chr_negative_prob

        self.X = adata.X
        self.n_cells, self.n_peaks = self.X.shape
        self.chr = adata.var["Chromosome"].values
        self.start = adata.var["Start"].values
        self.end = adata.var["End"].values

        # Negative sampling distribution
        self.neg_distribution = torch.from_numpy(adata.var["neg"].values)
        self.neg_cat_all = torch.distributions.categorical.Categorical(probs=self.neg_distribution)

        self.by_chr = {}
        self.neg_cat_chr = {}
        for u in np.unique(self.chr):
            idxs = np.where(self.chr == u)[0]
            self.by_chr[u] = idxs
            f = (adata.var.cisTopic_nr_acc.values[idxs].astype(np.float64) ** 0.75)
            self.neg_cat_chr[u] = torch.distributions.categorical.Categorical(
                probs=torch.from_numpy(f / (f.sum() + 1e-12)).float()
            )

        # Subsampling distribution
        self.keep_distribution = adata.var["keep"].values

        # Counter
        self.counter = defaultdict(int)

    def _open_cell_peaks(self, cell_idx, rng):
        start, end = self.X.indptr[cell_idx], self.X.indptr[cell_idx + 1]
        peaks = self.X.indices[start:end]
        if peaks.size < 2:
            return peaks
        #print(cell_idx)
        #print(self.chr[peaks].value_counts())
        mask = rng.random(peaks.size) < self.keep_distribution[peaks]
        peaks = peaks[mask] if mask.any() else peaks
        return peaks
    
    def _sample_pair(self, peak_idx, open_peaks, rng):
        chr = self.chr[peak_idx]
        c_mid = (self.start[peak_idx] + self.end[peak_idx]) // 2

        if rng.random() > self.trans_fraction:
            candidates = open_peaks[(self.chr[open_peaks] == chr) & (open_peaks != peak_idx)]
            if candidates.size > 0:
                mids = (self.start[candidates] + self.end[candidates]) // 2
                distances = np.abs(mids - c_mid)
                in_cis_window = distances <= self.cis_window
                if in_cis_window.any():
                    weights = np.exp(-distances[in_cis_window] / self.cis_window)
                    weights = weights / (weights.sum() + 1e-12)
                    return int(rng.choice(candidates[in_cis_window], p=weights))


        paired_peaks = open_peaks[open_peaks != peak_idx]
        return int(rng.choice(paired_peaks)) if paired_peaks.size > 0 else None
    
    def _sample_negatives(self, peak_idx, pair_idx, rng):
        if rng.random() < self.same_chr_negative_prob:
            chr = self.chr[peak_idx]
            idxs = self.by_chr[chr]
            draws = self.neg_cat_chr[chr].sample((self.n_negative,))
            negatives = torch.from_numpy(idxs[draws.numpy().astype(int)])
        else:
            negatives = self.neg_cat_all.sample((self.n_negative,))

        if isinstance(negatives, torch.Tensor):
            negatives = torch.where(negatives == peak_idx, (negatives + 1) % self.n_peaks, negatives)
            negatives = torch.where(negatives == pair_idx, (negatives + 2) % self.n_peaks, negatives)
        return negatives

    def __iter__(self):
        wi = get_worker_info()
        worker_id = wi.id if wi else 0
        rng = np.random.Generator(np.random.PCG64(self.seed + 1337 * (worker_id + 1)))

        produced = 0
        while produced < self.samples_per_epoch:
            cell_idx = rng.integers(0, self.n_cells)
            open_peaks = self._open_cell_peaks(cell_idx, rng)
            if open_peaks.size < 2:
                continue

            sampled_peaks = rng.choice(open_peaks, size=self.n_pairs, replace=(len(open_peaks) < self.n_pairs))
            #print(self.chr[sampled_peaks].to_list())
            for peak_idx in sampled_peaks:
                #print(self.chr[peak_idx])
                pair_idx = self._sample_pair(peak_idx, open_peaks, rng)
                if pair_idx is None:
                    continue

                negatives = self._sample_negatives(peak_idx, pair_idx, rng)
                self.counter[self.chr[peak_idx]] += 1
                yield int(peak_idx), int(pair_idx), negatives

                produced += 1
                if produced >= self.samples_per_epoch:
                    break

# %% [markdown]
# ## DataLoader

# %%
def peak2vec_collate(batch):
    peaks, peak_pairs, negatives = zip(*batch)
    peaks = torch.tensor(peaks, dtype=torch.long)
    peak_pairs = torch.tensor(peak_pairs, dtype=torch.long)
    negatives = torch.stack(negatives, dim=0).long()
    return peaks, peak_pairs, negatives

# %%
dataset1 = PeakDataset(adata, samples_per_epoch=20000, n_pairs=20, n_negative=15, seed=4, trans_fraction=0.2, cis_window=500000, same_chr_negative_prob=0.5)
loader1 = DataLoader(dataset1, batch_size=512, collate_fn=peak2vec_collate, num_workers=0, pin_memory=True)

# %%
iterator = iter(loader1)

# %%
peaks, peak_pairs, negatives = next(iterator)
peaks.size(), peak_pairs.size(), negatives.size(), dataset1.counter, peaks, peak_pairs
# Out:
# (torch.Size([512]),
#  torch.Size([512]),
#  torch.Size([512, 15]),
#  defaultdict(int,
#              {'chr19': 34,
#               'chr16': 20,
#               'chr4': 21,
#               'chrX': 18,
#               'chr9': 19,
#               'chr11': 30,
#               'chr12': 34,
#               'chr5': 21,
#               'chr15': 11,
#               'chr2': 31,
#               'chr7': 25,
#               'chr6': 38,
#               'chr17': 34,
#               'chr1': 52,
#               'chr20': 16,
#               'chr8': 16,
#               'chr10': 23,
#               'chr14': 17,
#               'chr13': 7,
#               'chr22': 10,
#               'chr18': 8,
#               'chr21': 8,
#               'chr3': 19}),
#  tensor([226798, 238875, 196541,  67443,  62192, 264731, 118001, 144188, 232197,
#          160633,  68621, 228474, 183987,  33266, 152824, 105580,  30359, 180226,
#          126531,  88785, 215245, 236872, 204253,  18814, 242572, 103225, 227252,
#          109046, 236136, 127691, 228076,  28389, 156424, 115995, 206744, 206460,
#          214249, 260192,  82339,  30799,  31147, 245469,   4993, 179104, 187187,
#          169958, 173196, 254611,  62193, 129257,   6177,  96317, 120044,  70587,
#          216445, 156625, 171078, 135626, 234089, 238730, 237840, 107976, 118746,
#           43211, 189030, 192589, 254492,   5737, 117238,  70082, 109369, 163298,
#           23597, 253750, 222257, 195441, 138738, 249576,  96176,  87893,  11983,
#           48105, 142571,   1685,  97495, 224453, 174357,  62066,   7915, 204252,
#           82914, 130519, 148882,  14555,  92997, 111939,   9485, 222999,   2332,
#          129901, 177207,  60893,  59566, 206455,   7312,  36596, 249374, 233925,
#          118531,  37369, 130488,  82839,  27030, 117731, 155333, 253560, 184803,
#          146193, 155696, 144704, 173770, 115644,  55818,  69652, 109068, 198549,
#          254677, 260000, 121653,  53179,  56573,  35144,  90390,  84169, 227808,
#          167048, 260152,  44388, 246205,  91941, 228948, 154998,  90880,  74692,
#           84286,  61568,  74142, 264105,  12072,  61109, 155766, 247049,  82120,
#          198425,  71210, 249595, 134915,  92418,  83480,  57496,  21247, 215260,
#          144109,  12278, 145178, 237721, 127971, 242395,  23930, 144833, 167735,
#          153636, 247634, 204009, 164414, 227950, 156171,  99791,  30977, 229327,
#          186885,   8916, 135217, 218635, 117702, 142341,  19556,  39881, 134224,
#           12773,  70117, 132924,  70417, 167406, 159979, 105787, 205478, 213106,
#            9199, 151985, 149562, 216248, 191552, 156037, 173369,   2845,  49448,
#          183365, 167631, 210622, 261269,  84218, 242188, 137652, 196917, 142092,
#          206661, 106971, 126526, 258619, 158664, 263272, 198205, 261536, 143238,
#          237127, 228708,  18889, 261855, 164828, 159597,  14689, 262545, 243777,
#          253719, 152026,  26839,  96891, 172720, 164274, 175221, 140898, 100818,
#          206862, 242572,  83683, 243101, 237528, 249262,  30641, 202953,  72867,
#            8689,  59853, 206901, 248508,  96419, 127254,  61807, 257143,  67815,
#          191130,  66889, 125565,  24861,   5281, 188774, 141239,   6215, 167113,
#           85301, 119322, 173982,   6410,  69479, 257001, 100829,  23975, 243102,
#           83961,  82089, 126591,  82841,  35144,  76875,  98277,   6613, 108398,
#          176691,  24688,  82311, 144355,  97185, 117471,  97561, 260889,   8936,
#           83384, 194777, 120184, 166888, 158099, 262840, 147273,  48235, 158016,
#           25510,  60913,  76270,  95395,  78549, 111070, 151313, 173835, 129094,
#          179774, 219679, 203904,  43754,  27480,  47323,  91756,  71765,  56190,
#          159130, 181550,  60980, 226578, 193664,  92066, 114125, 226270, 109546,
#           86639, 181127,  50338, 262213,   5653,  66222, 184690,  38029, 191480,
#          129749,  61137,  22948, 235530,   7234,  96321, 263647, 218247, 129045,
#           98050,  29464,  19820,   6757, 213048,  30293, 234050, 129389, 146452,
#            6756, 173584, 155036, 147747, 140658, 173378,  51488,  84167,  18895,
#          205935, 130988,  39917, 260907, 136692,  90608, 149443,  91434, 203987,
#           31343, 206369,  41255, 155571, 247561, 148685,  96901, 162067,  90996,
#          164288, 102814, 145776, 128631, 234702, 110041,  68351, 156379,  61607,
#           48258,  81200,  75810,   8698, 260972,  97756,  48710,  99599, 234769,
#          219667, 242610,  47584, 118152,   9397, 190542, 113885,  49222,  87988,
#           83948, 263596,  70044, 118697, 108039,  29652, 103431,  83551, 261256,
#           70046, 160674,  84013,    143, 215347,  31554, 173908, 219480, 219487,
#          249438,  66495,   5802, 217586,  57849,  36009, 191334, 225598, 165775,
#          251465,  83022, 219623,  97556,  82335, 233247,  66308, 194365, 130590,
#          197944, 196588, 194520,  63801,  22791, 212857, 152479, 126543, 162533,
#           69083, 177007,  21440, 205788, 233524,  91313,   9932, 248541, 207812,
#           12665, 250112, 157607,  34157, 145203,  67395, 206941, 248850, 207829,
#          225920,  19423,  97020, 109200, 148208,  49408, 157467, 164684, 184100,
#          119207, 227818, 146615, 216889,  60608, 163776, 206488, 144720,  85197,
#          220970,  55919,  55675,  36296, 242183, 102612,  31944, 128782, 206523,
#          183066,  21218,   6061, 109010, 258813, 228417,  33146,   6073]),
#  tensor([223431, 239757, 191171, 107942,  60500, 261469, 182259, 141643,  64929,
#          130174, 138053,   5798, 184020, 118734, 160454, 105409,  43746,  37996,
#          160723, 264892, 203963, 228486, 215394,   9170, 246250,  97058, 228649,
#          109049, 177405, 129349, 238904, 127686, 242980, 117898, 209889, 259578,
#          205338, 226870,  84225,  41370, 226848, 242549,  72749, 171552, 184530,
#          134946,  67462, 255997,  67393, 140676, 234080, 146544, 151100,  70571,
#          206710, 156644, 174014, 134483, 233257, 239093, 228089,   8318, 118750,
#           39987, 191486, 191486, 257299,  23233,  76459, 258623, 110542, 155192,
#            5872, 257006, 222269, 236177, 149402, 251712, 103790, 206718,   7368,
#          251323, 140269,   9044, 167986, 226751, 172649,  31591,  42222, 206910,
#          242897, 242064, 142719,   7853,  92759, 108728,   8676, 228524,  15889,
#          109404, 170869,  60176,  30794, 217514, 227977,  29626, 173569, 238109,
#          121816,  30647, 126777,  87886,  37512, 117727, 155332, 259535, 188357,
#          152485,   4210, 163159, 179599, 108243,  58683,  67580, 172901, 200446,
#          253296, 177661,  14090, 204951,  53058,  31337,  82585,  88234, 235086,
#          167591,  93813,  44351, 243078, 173858, 228131, 160948,  79260,  58060,
#           92764,   6729,  77695, 263025, 228602, 206946, 165677, 248000,  91957,
#          196837,  69958, 264742, 130151, 198580,  92481,  53955,  10901, 214428,
#          145178,  12284, 149307, 230944, 128606, 242394,   5522, 144828, 182292,
#          156790,  42729, 214104, 154246, 228465,  42196, 114319,  34550,  65140,
#          182455,  74950, 128521, 219450, 125525, 139269,  15348, 241913, 136772,
#          254267, 179659,  50164,  69153,  96317,   5594, 104685, 212453, 205217,
#            8330, 146525, 139710, 135047, 191544, 224867, 179721,  20920,  58969,
#          181918, 190638, 212651,   3213,  79436,  92184, 134929, 199086, 139773,
#          246621,   4587, 123741, 257543, 163844, 261011, 198660,  23446, 153256,
#          227862, 178943,  22676, 260790, 155164, 159587,    343, 263243,  72382,
#          254992, 139496,  29030,  89140, 178696,  84551,  22554,  14396,  26215,
#           29905, 146062,  87606, 130257, 226523, 113737,  41365, 141569,  58308,
#           18140, 143121, 202707, 244899, 178887, 155329,  61809, 228186,  76806,
#          155475,  61319, 116433,     85,   9969, 191130, 141247, 204424, 168040,
#           87362, 115951, 187142,  76885,  76468, 253728, 210465,  19890, 247467,
#           89824,  88435, 195190,  89972,  40946,  78458, 100774,  16815, 253613,
#          254438,  23490,  79504, 173276,  98277,   7137, 100058, 263553,   6571,
#           82267, 173538, 124523, 168939, 161594, 260711, 148319,  58980, 155507,
#            9189,  66638,  77838,  96152,  70521, 113286,   5961, 175527, 136975,
#          173496, 237557, 215244, 177512,  31719,  52347,  86634,  78361,  51825,
#          159123, 136568, 214731, 116834, 196645, 176144, 208209, 109808,  85209,
#           90095, 185594,  47846, 262225,   5620,  62209,  59774,  43169, 196871,
#           38029, 190821, 125301,  78361,  14462,  98194,  88686, 214596,  83630,
#           99301, 248499,  25975,  95802, 216115, 260692, 225693, 152113, 149390,
#          238202, 173580, 190991, 109316, 140651,  98175,   5287,  90608,   8434,
#          194171, 129029,  31103, 228647, 130534,  84297, 241938,  90415, 151675,
#           18890, 206386, 215357, 155580, 247104, 147972,  98019, 154985,  83271,
#          157411,  97235, 149804, 163000, 238947, 108323,  70748, 160165,  64460,
#           46837,  89813,  75901,   4858, 261524,  94938,  57997,  94516, 227564,
#          221647, 248198,  47595, 123110,   7581, 221647, 114888,  84251,   8669,
#           82157, 262255, 126518, 119254, 196629, 120938, 147505,  80346, 180638,
#           70044, 123030,  90761,  21169, 203146,  36956,  84058, 221039, 219471,
#            5421, 217645,   5834, 203299, 159151,  37831, 191335, 239985, 159939,
#          249350,  83023,  92215, 100056, 170858, 239201,  65775, 225040,  21744,
#          190808, 217508, 199630,  66523,   3371, 212093, 164215, 124943, 152479,
#           71023,  52584,  10165, 214862, 229724,   8989, 261962, 243573,  99353,
#           13795, 250858,  72556,  36570, 151419,  61668, 207989, 249233, 204657,
#          228158,  22144,  99288, 115533, 144702,  52538, 153761, 163106, 182494,
#           31777, 227822, 151049, 207470,  64694, 159849, 218122, 150109,  93335,
#           47773,  50196,  48761,  28990, 240546, 106108, 141179, 128777, 128987,
#            6709, 242387,   6073, 255921, 254509, 238895,  29929,  22831]))

# %% [markdown]
# ## Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Peak2Vec(nn.Module):
    def __init__(self, n_peaks, embedding_dim=64):
        super(Peak2Vec, self).__init__()
        self.dim = embedding_dim
        self.embedding = nn.Embedding(n_peaks, embedding_dim)
        
        self.reset_params()
    
    def reset_params(self):
        nn.init.uniform_(self.embedding.weight, -0.5 / self.dim, 0.5 / self.dim)

    def forward(self, peaks, peak_pairs, negatives):
        # Embeddings
        peak_emb = self.embedding(peaks)               # (B, D)
        pair_emb = self.embedding(peak_pairs)          # (B, D)
        neg_emb = self.embedding(negatives)            # (B, K, D)

        # Compute similarity scores
        pos_score = torch.sum(peak_emb * pair_emb, dim=1)                   # (B)
        neg_score = torch.bmm(neg_emb, peak_emb.unsqueeze(2)).squeeze(2)    # (B, K)

        # Loss
        poss_loss = F.softplus(-pos_score)         # -log(sigmoid(x)) = softplus(-x)
        neg_loss = F.softplus(neg_score).sum(1)      # -log(1 - sigmoid(x)) = softplus(x)
        loss = (poss_loss + neg_loss).mean()

        with torch.no_grad():
            stats = {
                "pos_score_mean": pos_score.mean().detach(),
                "neg_score_mean": neg_score.mean().detach(),
                "pos_loss_mean":  poss_loss.mean().detach(),
                "neg_loss_mean":  neg_loss.mean().detach(),
            }
        return loss, stats
    
    @torch.no_grad()
    def get_peak_embeddings(self, normalize=True):
        embeddings = self.embedding.weight.detach().cpu()
        if normalize:
            embeddings = F.normalize(embeddings, p=2, dim=1)
        return embeddings
    
    @torch.no_grad()
    def most_similar(self, peak_idx, topk=10):
        embeddings = self.get_peak_embeddings(normalize=True)  # (N, D)
        peak_emb = embeddings[peak_idx:peak_idx+1]          # (1, D)
        similarities = (embeddings @ peak_emb.t()).squeeze(1)  # (N)
        values, indices = torch.topk(similarities, topk + 1, embeddings.size(0), largest=True)
        # drop self if in topk
        if indices and indices[0] == peak_idx:
            indices, values = indices[1:], values[1:]
        return indices[:topk], values[:topk]

# %% [markdown]
# ## Training

# %%
seed = 4
n_pairs = 20
n_negative = 20
samples_per_epoch = 20000
batch_size = 512
embedding_dim = 128
trans_fraction=0.2
cis_window=500000
same_chr_negative_prob=0.5
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
dataset = PeakDataset(
    adata,
    samples_per_epoch=samples_per_epoch,
    n_pairs=n_pairs,
    n_negative=n_negative,
    seed=seed,
    trans_fraction=trans_fraction,
    cis_window=cis_window,
    same_chr_negative_prob=same_chr_negative_prob,
    # cis_distance_func="exp",
    # cis_distance_param=5e5
)

loader = DataLoader(
    dataset,
    batch_size=batch_size,
    collate_fn=peak2vec_collate,
    num_workers=0,
    pin_memory=True
)

# %%
model = Peak2Vec(adata.n_vars, embedding_dim=embedding_dim).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=2e-3)

# %%
history = list()

# %%
num_epochs = 2000

for epoch in range(1, num_epochs + 1):
    model.train()

    running = 0.0
    running_pos = 0.0
    running_neg = 0.0
    #dataset.set_epoch(epoch)
    for step, (peaks, peak_pairs, negatives) in enumerate(loader, 1):
        peaks = peaks.to(device, non_blocking=True)
        peak_pairs = peak_pairs.to(device, non_blocking=True)
        negatives = negatives.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        loss, stats = model(peaks, peak_pairs, negatives)
        loss.backward()
        
        optimizer.step()

        running += float(loss.detach().cpu())
        running_pos += float(stats["pos_loss_mean"].cpu())
        running_neg += float(stats["neg_loss_mean"].cpu())

        #print(f"Epoch {epoch} | Step {step:03d} | Loss: {running / step:.4f} | Pos Loss: {stats['pos_loss_mean']:.4f} | Neg Loss: {stats['neg_loss_mean']:.4f} | Pos Score: {stats['pos_score_mean']:.4f} | Neg Score: {stats['neg_score_mean']:.4f}")
    
    # Log epoch stats
    stats["running_loss"] = running / step
    stats["pos_loss_mean"] = running_pos / step
    stats["neg_loss_mean"] = running_neg / step
    history.append(stats)
    print(f"Epoch {epoch} | Step {step:03d} | Loss: {running / step:.6f} | Pos Loss: {stats['pos_loss_mean']:.6f} | Neg Loss: {stats['neg_loss_mean']:.6f} | Pos Score: {stats['pos_score_mean']:.6f} | Neg Score: {stats['neg_score_mean']:.6f}")
# Out:
# Epoch 1 | Step 040 | Loss: 14.556115 | Pos Loss: 0.693144 | Neg Loss: 13.862971 | Pos Score: 0.000228 | Neg Score: 0.000007
# Epoch 2 | Step 040 | Loss: 14.551936 | Pos Loss: 0.689311 | Neg Loss: 13.862625 | Pos Score: 0.015822 | Neg Score: -0.000181
# Epoch 3 | Step 040 | Loss: 14.539087 | Pos Loss: 0.678138 | Neg Loss: 13.860949 | Pos Score: 0.054474 | Neg Score: 0.000114
# Epoch 4 | Step 040 | Loss: 14.513506 | Pos Loss: 0.660250 | Neg Loss: 13.853256 | Pos Score: 0.109184 | Neg Score: -0.001577
# Epoch 5 | Step 040 | Loss: 14.462145 | Pos Loss: 0.635676 | Neg Loss: 13.826469 | Pos Score: 0.189970 | Neg Score: -0.007518
# Epoch 6 | Step 040 | Loss: 14.358059 | Pos Loss: 0.605268 | Neg Loss: 13.752791 | Pos Score: 0.300107 | Neg Score: -0.018992
# Epoch 7 | Step 040 | Loss: 14.154026 | Pos Loss: 0.570830 | Neg Loss: 13.583196 | Pos Score: 0.437654 | Neg Score: -0.047151
# Epoch 8 | Step 040 | Loss: 13.792531 | Pos Loss: 0.534735 | Neg Loss: 13.257796 | Pos Score: 0.608063 | Neg Score: -0.102582
# Epoch 9 | Step 040 | Loss: 13.235823 | Pos Loss: 0.500127 | Neg Loss: 12.735696 | Pos Score: 0.815383 | Neg Score: -0.170537
# Epoch 10 | Step 040 | Loss: 12.479305 | Pos Loss: 0.469743 | Neg Loss: 12.009562 | Pos Score: 1.050746 | Neg Score: -0.319303
# Epoch 11 | Step 040 | Loss: 11.617040 | Pos Loss: 0.445921 | Neg Loss: 11.171119 | Pos Score: 1.309296 | Neg Score: -0.488307
# Epoch 12 | Step 040 | Loss: 10.743504 | Pos Loss: 0.427103 | Neg Loss: 10.316401 | Pos Score: 1.574077 | Neg Score: -0.712334
# Epoch 13 | Step 040 | Loss: 9.975531 | Pos Loss: 0.410734 | Neg Loss: 9.564797 | Pos Score: 1.827197 | Neg Score: -0.862599
# Epoch 14 | Step 040 | Loss: 9.290610 | Pos Loss: 0.395174 | Neg Loss: 8.895436 | Pos Score: 2.043172 | Neg Score: -1.145834
# Epoch 15 | Step 040 | Loss: 8.753142 | Pos Loss: 0.378248 | Neg Loss: 8.374894 | Pos Score: 2.243992 | Neg Score: -1.171393
# Epoch 16 | Step 040 | Loss: 8.269810 | Pos Loss: 0.358814 | Neg Loss: 7.910996 | Pos Score: 2.389789 | Neg Score: -1.479342
# Epoch 17 | Step 040 | Loss: 7.898022 | Pos Loss: 0.338762 | Neg Loss: 7.559259 | Pos Score: 2.543138 | Neg Score: -1.635444
# Epoch 18 | Step 040 | Loss: 7.568020 | Pos Loss: 0.317903 | Neg Loss: 7.250118 | Pos Score: 2.653986 | Neg Score: -1.769644
# Epoch 19 | Step 040 | Loss: 7.307178 | Pos Loss: 0.297178 | Neg Loss: 7.009999 | Pos Score: 2.732411 | Neg Score: -1.880949
# Epoch 20 | Step 040 | Loss: 7.027120 | Pos Loss: 0.277027 | Neg Loss: 6.750093 | Pos Score: 2.779190 | Neg Score: -2.092584
# Epoch 21 | Step 040 | Loss: 6.802190 | Pos Loss: 0.258530 | Neg Loss: 6.543660 | Pos Score: 2.854702 | Neg Score: -2.099743
# Epoch 22 | Step 040 | Loss: 6.638206 | Pos Loss: 0.241587 | Neg Loss: 6.396619 | Pos Score: 2.888736 | Neg Score: -2.267073
# Epoch 23 | Step 040 | Loss: 6.443393 | Pos Loss: 0.225886 | Neg Loss: 6.217507 | Pos Score: 2.925894 | Neg Score: -2.323943
# Epoch 24 | Step 040 | Loss: 6.285559 | Pos Loss: 0.211751 | Neg Loss: 6.073809 | Pos Score: 2.982948 | Neg Score: -2.485746
# Epoch 25 | Step 040 | Loss: 6.153952 | Pos Loss: 0.198510 | Neg Loss: 5.955442 | Pos Score: 3.031785 | Neg Score: -2.527340
# Epoch 26 | Step 040 | Loss: 6.018648 | Pos Loss: 0.186719 | Neg Loss: 5.831928 | Pos Score: 3.062783 | Neg Score: -2.717658
# Epoch 27 | Step 040 | Loss: 5.878443 | Pos Loss: 0.176109 | Neg Loss: 5.702333 | Pos Score: 3.113774 | Neg Score: -2.825335
# Epoch 28 | Step 040 | Loss: 5.782950 | Pos Loss: 0.166580 | Neg Loss: 5.616371 | Pos Score: 3.159311 | Neg Score: -2.750919
# Epoch 29 | Step 040 | Loss: 5.656293 | Pos Loss: 0.158070 | Neg Loss: 5.498222 | Pos Score: 3.193254 | Neg Score: -2.989665
# Epoch 30 | Step 040 | Loss: 5.612899 | Pos Loss: 0.150498 | Neg Loss: 5.462401 | Pos Score: 3.229769 | Neg Score: -2.748456
# Epoch 31 | Step 040 | Loss: 5.493226 | Pos Loss: 0.143300 | Neg Loss: 5.349926 | Pos Score: 3.221072 | Neg Score: -2.838197
# Epoch 32 | Step 040 | Loss: 5.405231 | Pos Loss: 0.136819 | Neg Loss: 5.268412 | Pos Score: 3.237897 | Neg Score: -2.897660
# Epoch 33 | Step 040 | Loss: 5.299670 | Pos Loss: 0.130627 | Neg Loss: 5.169044 | Pos Score: 3.274978 | Neg Score: -2.980867
# Epoch 34 | Step 040 | Loss: 5.247028 | Pos Loss: 0.124911 | Neg Loss: 5.122117 | Pos Score: 3.294338 | Neg Score: -3.135691
# Epoch 35 | Step 040 | Loss: 5.157978 | Pos Loss: 0.119868 | Neg Loss: 5.038110 | Pos Score: 3.308277 | Neg Score: -3.007213
# Epoch 36 | Step 040 | Loss: 5.105272 | Pos Loss: 0.115143 | Neg Loss: 4.990128 | Pos Score: 3.339386 | Neg Score: -2.969128
# Epoch 37 | Step 040 | Loss: 5.034323 | Pos Loss: 0.110692 | Neg Loss: 4.923631 | Pos Score: 3.374628 | Neg Score: -2.948615
# Epoch 38 | Step 040 | Loss: 4.976697 | Pos Loss: 0.106556 | Neg Loss: 4.870141 | Pos Score: 3.395770 | Neg Score: -2.973933
# Epoch 39 | Step 040 | Loss: 4.890744 | Pos Loss: 0.102943 | Neg Loss: 4.787801 | Pos Score: 3.403152 | Neg Score: -3.147556
# Epoch 40 | Step 040 | Loss: 4.879103 | Pos Loss: 0.099314 | Neg Loss: 4.779790 | Pos Score: 3.471099 | Neg Score: -2.930382
# Epoch 41 | Step 040 | Loss: 4.803276 | Pos Loss: 0.095868 | Neg Loss: 4.707409 | Pos Score: 3.469723 | Neg Score: -3.002484
# Epoch 42 | Step 040 | Loss: 4.755214 | Pos Loss: 0.092663 | Neg Loss: 4.662551 | Pos Score: 3.463788 | Neg Score: -3.140630
# Epoch 43 | Step 040 | Loss: 4.685539 | Pos Loss: 0.089827 | Neg Loss: 4.595712 | Pos Score: 3.459350 | Neg Score: -3.105305
# Epoch 44 | Step 040 | Loss: 4.638700 | Pos Loss: 0.087090 | Neg Loss: 4.551610 | Pos Score: 3.502370 | Neg Score: -3.172178
# Epoch 45 | Step 040 | Loss: 4.567899 | Pos Loss: 0.084596 | Neg Loss: 4.483303 | Pos Score: 3.533117 | Neg Score: -3.225457
# Epoch 46 | Step 040 | Loss: 4.577424 | Pos Loss: 0.082257 | Neg Loss: 4.495166 | Pos Score: 3.551350 | Neg Score: -3.227548
# Epoch 47 | Step 040 | Loss: 4.492409 | Pos Loss: 0.079901 | Neg Loss: 4.412509 | Pos Score: 3.547394 | Neg Score: -3.272730
# Epoch 48 | Step 040 | Loss: 4.461558 | Pos Loss: 0.077718 | Neg Loss: 4.383840 | Pos Score: 3.579756 | Neg Score: -3.381620
# Epoch 49 | Step 040 | Loss: 4.425168 | Pos Loss: 0.075618 | Neg Loss: 4.349550 | Pos Score: 3.592641 | Neg Score: -3.313899
# Epoch 50 | Step 040 | Loss: 4.387262 | Pos Loss: 0.073602 | Neg Loss: 4.313660 | Pos Score: 3.658938 | Neg Score: -3.373082
# Epoch 51 | Step 040 | Loss: 4.371993 | Pos Loss: 0.071657 | Neg Loss: 4.300336 | Pos Score: 3.695753 | Neg Score: -3.345966
# Epoch 52 | Step 040 | Loss: 4.309305 | Pos Loss: 0.069920 | Neg Loss: 4.239385 | Pos Score: 3.736921 | Neg Score: -3.325868
# Epoch 53 | Step 040 | Loss: 4.280437 | Pos Loss: 0.068280 | Neg Loss: 4.212157 | Pos Score: 3.749254 | Neg Score: -3.337557
# Epoch 54 | Step 040 | Loss: 4.260237 | Pos Loss: 0.066543 | Neg Loss: 4.193694 | Pos Score: 3.730272 | Neg Score: -3.346787
# Epoch 55 | Step 040 | Loss: 4.241344 | Pos Loss: 0.064972 | Neg Loss: 4.176372 | Pos Score: 3.738910 | Neg Score: -3.275788
# Epoch 56 | Step 040 | Loss: 4.188287 | Pos Loss: 0.063388 | Neg Loss: 4.124899 | Pos Score: 3.787455 | Neg Score: -3.350832
# Epoch 57 | Step 040 | Loss: 4.194585 | Pos Loss: 0.061914 | Neg Loss: 4.132671 | Pos Score: 3.812892 | Neg Score: -3.324634
# Epoch 58 | Step 040 | Loss: 4.142521 | Pos Loss: 0.060506 | Neg Loss: 4.082015 | Pos Score: 3.831537 | Neg Score: -3.482101
# Epoch 59 | Step 040 | Loss: 4.101134 | Pos Loss: 0.059178 | Neg Loss: 4.041957 | Pos Score: 3.856955 | Neg Score: -3.372754
# Epoch 60 | Step 040 | Loss: 4.064811 | Pos Loss: 0.057905 | Neg Loss: 4.006906 | Pos Score: 3.877754 | Neg Score: -3.463853
# Epoch 61 | Step 040 | Loss: 4.066291 | Pos Loss: 0.056721 | Neg Loss: 4.009570 | Pos Score: 3.914844 | Neg Score: -3.498079
# Epoch 62 | Step 040 | Loss: 4.007818 | Pos Loss: 0.055567 | Neg Loss: 3.952250 | Pos Score: 3.906459 | Neg Score: -3.427890
# Epoch 63 | Step 040 | Loss: 4.004059 | Pos Loss: 0.054461 | Neg Loss: 3.949598 | Pos Score: 3.925282 | Neg Score: -3.439377
# Epoch 64 | Step 040 | Loss: 4.000146 | Pos Loss: 0.053365 | Neg Loss: 3.946781 | Pos Score: 3.907724 | Neg Score: -3.361908
# Epoch 65 | Step 040 | Loss: 3.945153 | Pos Loss: 0.052279 | Neg Loss: 3.892873 | Pos Score: 3.902252 | Neg Score: -3.484150
# Epoch 66 | Step 040 | Loss: 3.922834 | Pos Loss: 0.051256 | Neg Loss: 3.871578 | Pos Score: 3.930701 | Neg Score: -3.463233
# Epoch 67 | Step 040 | Loss: 3.920498 | Pos Loss: 0.050282 | Neg Loss: 3.870217 | Pos Score: 3.946902 | Neg Score: -3.436739
# Epoch 68 | Step 040 | Loss: 3.894018 | Pos Loss: 0.049359 | Neg Loss: 3.844660 | Pos Score: 3.989660 | Neg Score: -3.485401
# Epoch 69 | Step 040 | Loss: 3.840022 | Pos Loss: 0.048446 | Neg Loss: 3.791576 | Pos Score: 4.010523 | Neg Score: -3.633507
# Epoch 70 | Step 040 | Loss: 3.843836 | Pos Loss: 0.047575 | Neg Loss: 3.796260 | Pos Score: 4.007412 | Neg Score: -3.594753
# Epoch 71 | Step 040 | Loss: 3.793971 | Pos Loss: 0.046821 | Neg Loss: 3.747150 | Pos Score: 4.054858 | Neg Score: -3.501909
# Epoch 72 | Step 040 | Loss: 3.797252 | Pos Loss: 0.045963 | Neg Loss: 3.751289 | Pos Score: 4.104180 | Neg Score: -3.644714
# Epoch 73 | Step 040 | Loss: 3.758329 | Pos Loss: 0.045108 | Neg Loss: 3.713221 | Pos Score: 4.130283 | Neg Score: -3.763570
# Epoch 74 | Step 040 | Loss: 3.754557 | Pos Loss: 0.044261 | Neg Loss: 3.710296 | Pos Score: 4.123630 | Neg Score: -3.655234
# Epoch 75 | Step 040 | Loss: 3.708225 | Pos Loss: 0.043517 | Neg Loss: 3.664707 | Pos Score: 4.186311 | Neg Score: -3.671810
# Epoch 76 | Step 040 | Loss: 3.693567 | Pos Loss: 0.042865 | Neg Loss: 3.650702 | Pos Score: 4.164406 | Neg Score: -3.648657
# Epoch 77 | Step 040 | Loss: 3.678778 | Pos Loss: 0.042162 | Neg Loss: 3.636616 | Pos Score: 4.181230 | Neg Score: -3.727786
# Epoch 78 | Step 040 | Loss: 3.672402 | Pos Loss: 0.041508 | Neg Loss: 3.630895 | Pos Score: 4.219553 | Neg Score: -3.859784
# Epoch 79 | Step 040 | Loss: 3.636920 | Pos Loss: 0.040858 | Neg Loss: 3.596061 | Pos Score: 4.231185 | Neg Score: -3.869749
# Epoch 80 | Step 040 | Loss: 3.651318 | Pos Loss: 0.040190 | Neg Loss: 3.611128 | Pos Score: 4.283485 | Neg Score: -3.759406
# Epoch 81 | Step 040 | Loss: 3.632435 | Pos Loss: 0.039435 | Neg Loss: 3.593000 | Pos Score: 4.326746 | Neg Score: -3.650475
# Epoch 82 | Step 040 | Loss: 3.622274 | Pos Loss: 0.038829 | Neg Loss: 3.583446 | Pos Score: 4.320764 | Neg Score: -3.669862
# Epoch 83 | Step 040 | Loss: 3.584507 | Pos Loss: 0.038188 | Neg Loss: 3.546319 | Pos Score: 4.295859 | Neg Score: -3.843415
# Epoch 84 | Step 040 | Loss: 3.584292 | Pos Loss: 0.037728 | Neg Loss: 3.546564 | Pos Score: 4.305304 | Neg Score: -3.779387
# Epoch 85 | Step 040 | Loss: 3.553110 | Pos Loss: 0.037146 | Neg Loss: 3.515964 | Pos Score: 4.326561 | Neg Score: -3.772813
# Epoch 86 | Step 040 | Loss: 3.563926 | Pos Loss: 0.036584 | Neg Loss: 3.527341 | Pos Score: 4.347342 | Neg Score: -3.834372
# Epoch 87 | Step 040 | Loss: 3.531895 | Pos Loss: 0.036064 | Neg Loss: 3.495831 | Pos Score: 4.347604 | Neg Score: -3.828583
# Epoch 88 | Step 040 | Loss: 3.514624 | Pos Loss: 0.035638 | Neg Loss: 3.478986 | Pos Score: 4.365843 | Neg Score: -3.902936
# Epoch 89 | Step 040 | Loss: 3.499552 | Pos Loss: 0.035225 | Neg Loss: 3.464326 | Pos Score: 4.378885 | Neg Score: -3.761150
# Epoch 90 | Step 040 | Loss: 3.490466 | Pos Loss: 0.034714 | Neg Loss: 3.455752 | Pos Score: 4.375163 | Neg Score: -3.758143
# Epoch 91 | Step 040 | Loss: 3.463479 | Pos Loss: 0.034231 | Neg Loss: 3.429248 | Pos Score: 4.383364 | Neg Score: -3.934528
# Epoch 92 | Step 040 | Loss: 3.485902 | Pos Loss: 0.033653 | Neg Loss: 3.452249 | Pos Score: 4.441846 | Neg Score: -3.754653
# Epoch 93 | Step 040 | Loss: 3.425779 | Pos Loss: 0.033259 | Neg Loss: 3.392521 | Pos Score: 4.430883 | Neg Score: -3.713763
# Epoch 94 | Step 040 | Loss: 3.441153 | Pos Loss: 0.032887 | Neg Loss: 3.408266 | Pos Score: 4.436468 | Neg Score: -3.801925
# Epoch 95 | Step 040 | Loss: 3.430301 | Pos Loss: 0.032434 | Neg Loss: 3.397867 | Pos Score: 4.487779 | Neg Score: -3.823681
# Epoch 96 | Step 040 | Loss: 3.384941 | Pos Loss: 0.031958 | Neg Loss: 3.352983 | Pos Score: 4.541156 | Neg Score: -3.901700
# Epoch 97 | Step 040 | Loss: 3.393620 | Pos Loss: 0.031647 | Neg Loss: 3.361973 | Pos Score: 4.522822 | Neg Score: -3.838722
# Epoch 98 | Step 040 | Loss: 3.396149 | Pos Loss: 0.031211 | Neg Loss: 3.364937 | Pos Score: 4.539670 | Neg Score: -3.825682
# Epoch 99 | Step 040 | Loss: 3.361948 | Pos Loss: 0.030830 | Neg Loss: 3.331118 | Pos Score: 4.553358 | Neg Score: -4.022712
# Epoch 100 | Step 040 | Loss: 3.337556 | Pos Loss: 0.030491 | Neg Loss: 3.307065 | Pos Score: 4.533160 | Neg Score: -3.826421
# Epoch 101 | Step 040 | Loss: 3.312340 | Pos Loss: 0.030164 | Neg Loss: 3.282176 | Pos Score: 4.547236 | Neg Score: -3.992653
# Epoch 102 | Step 040 | Loss: 3.341367 | Pos Loss: 0.029786 | Neg Loss: 3.311581 | Pos Score: 4.548914 | Neg Score: -3.915281
# Epoch 103 | Step 040 | Loss: 3.300305 | Pos Loss: 0.029393 | Neg Loss: 3.270912 | Pos Score: 4.583507 | Neg Score: -3.942765
# Epoch 104 | Step 040 | Loss: 3.301580 | Pos Loss: 0.029033 | Neg Loss: 3.272546 | Pos Score: 4.607847 | Neg Score: -4.019573
# Epoch 105 | Step 040 | Loss: 3.308374 | Pos Loss: 0.028729 | Neg Loss: 3.279645 | Pos Score: 4.604136 | Neg Score: -3.872791
# Epoch 106 | Step 040 | Loss: 3.259981 | Pos Loss: 0.028422 | Neg Loss: 3.231560 | Pos Score: 4.609144 | Neg Score: -3.979010
# Epoch 107 | Step 040 | Loss: 3.267279 | Pos Loss: 0.028148 | Neg Loss: 3.239131 | Pos Score: 4.617732 | Neg Score: -4.104626
# Epoch 108 | Step 040 | Loss: 3.246524 | Pos Loss: 0.027785 | Neg Loss: 3.218739 | Pos Score: 4.636792 | Neg Score: -3.953943
# Epoch 109 | Step 040 | Loss: 3.237855 | Pos Loss: 0.027600 | Neg Loss: 3.210255 | Pos Score: 4.632186 | Neg Score: -3.930844
# Epoch 110 | Step 040 | Loss: 3.236713 | Pos Loss: 0.027299 | Neg Loss: 3.209415 | Pos Score: 4.627219 | Neg Score: -4.023115
# Epoch 111 | Step 040 | Loss: 3.201832 | Pos Loss: 0.026930 | Neg Loss: 3.174901 | Pos Score: 4.628834 | Neg Score: -3.998156
# Epoch 112 | Step 040 | Loss: 3.221294 | Pos Loss: 0.026658 | Neg Loss: 3.194636 | Pos Score: 4.670231 | Neg Score: -4.017806
# Epoch 113 | Step 040 | Loss: 3.210061 | Pos Loss: 0.026364 | Neg Loss: 3.183697 | Pos Score: 4.684763 | Neg Score: -4.100924
# Epoch 114 | Step 040 | Loss: 3.186904 | Pos Loss: 0.026116 | Neg Loss: 3.160788 | Pos Score: 4.719342 | Neg Score: -3.999175
# Epoch 115 | Step 040 | Loss: 3.176030 | Pos Loss: 0.025833 | Neg Loss: 3.150198 | Pos Score: 4.714417 | Neg Score: -3.979371
# Epoch 116 | Step 040 | Loss: 3.170786 | Pos Loss: 0.025552 | Neg Loss: 3.145234 | Pos Score: 4.727644 | Neg Score: -3.931743
# Epoch 117 | Step 040 | Loss: 3.162018 | Pos Loss: 0.025276 | Neg Loss: 3.136743 | Pos Score: 4.735427 | Neg Score: -3.895291
# Epoch 118 | Step 040 | Loss: 3.180294 | Pos Loss: 0.025072 | Neg Loss: 3.155222 | Pos Score: 4.732267 | Neg Score: -3.936293
# Epoch 119 | Step 040 | Loss: 3.127601 | Pos Loss: 0.024815 | Neg Loss: 3.102787 | Pos Score: 4.722839 | Neg Score: -3.966232
# Epoch 120 | Step 040 | Loss: 3.130515 | Pos Loss: 0.024621 | Neg Loss: 3.105894 | Pos Score: 4.748480 | Neg Score: -3.988238
# Epoch 121 | Step 040 | Loss: 3.124792 | Pos Loss: 0.024397 | Neg Loss: 3.100396 | Pos Score: 4.783890 | Neg Score: -4.017999
# Epoch 122 | Step 040 | Loss: 3.110615 | Pos Loss: 0.024149 | Neg Loss: 3.086466 | Pos Score: 4.755805 | Neg Score: -4.143688
# Epoch 123 | Step 040 | Loss: 3.090101 | Pos Loss: 0.023832 | Neg Loss: 3.066269 | Pos Score: 4.805071 | Neg Score: -4.254775
# Epoch 124 | Step 040 | Loss: 3.100632 | Pos Loss: 0.023620 | Neg Loss: 3.077012 | Pos Score: 4.820076 | Neg Score: -4.202367
# Epoch 125 | Step 040 | Loss: 3.067549 | Pos Loss: 0.023421 | Neg Loss: 3.044128 | Pos Score: 4.831825 | Neg Score: -4.316330
# Epoch 126 | Step 040 | Loss: 3.080490 | Pos Loss: 0.023197 | Neg Loss: 3.057292 | Pos Score: 4.838800 | Neg Score: -4.170710
# Epoch 127 | Step 040 | Loss: 3.078775 | Pos Loss: 0.023037 | Neg Loss: 3.055738 | Pos Score: 4.867455 | Neg Score: -4.101569
# Epoch 128 | Step 040 | Loss: 3.055625 | Pos Loss: 0.022767 | Neg Loss: 3.032858 | Pos Score: 4.910558 | Neg Score: -4.250455
# Epoch 129 | Step 040 | Loss: 3.065611 | Pos Loss: 0.022616 | Neg Loss: 3.042995 | Pos Score: 4.903810 | Neg Score: -4.049847
# Epoch 130 | Step 040 | Loss: 3.075667 | Pos Loss: 0.022380 | Neg Loss: 3.053287 | Pos Score: 4.866766 | Neg Score: -4.260878
# Epoch 131 | Step 040 | Loss: 3.051962 | Pos Loss: 0.022137 | Neg Loss: 3.029825 | Pos Score: 4.871597 | Neg Score: -4.133235
# Epoch 132 | Step 040 | Loss: 3.032262 | Pos Loss: 0.021997 | Neg Loss: 3.010265 | Pos Score: 4.900746 | Neg Score: -4.291152
# Epoch 133 | Step 040 | Loss: 3.038501 | Pos Loss: 0.021786 | Neg Loss: 3.016715 | Pos Score: 4.891109 | Neg Score: -4.260876
# Epoch 134 | Step 040 | Loss: 2.994517 | Pos Loss: 0.021608 | Neg Loss: 2.972910 | Pos Score: 4.909893 | Neg Score: -4.264844
# Epoch 135 | Step 040 | Loss: 3.017684 | Pos Loss: 0.021439 | Neg Loss: 2.996245 | Pos Score: 4.940859 | Neg Score: -4.103913
# Epoch 136 | Step 040 | Loss: 3.016986 | Pos Loss: 0.021172 | Neg Loss: 2.995815 | Pos Score: 4.964999 | Neg Score: -4.117143
# Epoch 137 | Step 040 | Loss: 2.983840 | Pos Loss: 0.020988 | Neg Loss: 2.962852 | Pos Score: 4.955798 | Neg Score: -4.142306
# Epoch 138 | Step 040 | Loss: 2.989736 | Pos Loss: 0.020851 | Neg Loss: 2.968886 | Pos Score: 4.982541 | Neg Score: -4.246928
# Epoch 139 | Step 040 | Loss: 2.972364 | Pos Loss: 0.020685 | Neg Loss: 2.951679 | Pos Score: 5.031019 | Neg Score: -4.395971
# Epoch 140 | Step 040 | Loss: 2.980524 | Pos Loss: 0.020573 | Neg Loss: 2.959952 | Pos Score: 5.022814 | Neg Score: -4.255295
# Epoch 141 | Step 040 | Loss: 2.937620 | Pos Loss: 0.020374 | Neg Loss: 2.917246 | Pos Score: 5.088904 | Neg Score: -4.393431
# Epoch 142 | Step 040 | Loss: 2.945536 | Pos Loss: 0.020249 | Neg Loss: 2.925287 | Pos Score: 5.075744 | Neg Score: -4.490213
# Epoch 143 | Step 040 | Loss: 2.946550 | Pos Loss: 0.020114 | Neg Loss: 2.926436 | Pos Score: 5.075308 | Neg Score: -4.433045
# Epoch 144 | Step 040 | Loss: 2.938009 | Pos Loss: 0.019866 | Neg Loss: 2.918143 | Pos Score: 5.058700 | Neg Score: -4.384151
# Epoch 145 | Step 040 | Loss: 2.926851 | Pos Loss: 0.019693 | Neg Loss: 2.907158 | Pos Score: 5.081086 | Neg Score: -4.339041
# Epoch 146 | Step 040 | Loss: 2.921765 | Pos Loss: 0.019555 | Neg Loss: 2.902211 | Pos Score: 5.076134 | Neg Score: -4.483119
# Epoch 147 | Step 040 | Loss: 2.926296 | Pos Loss: 0.019409 | Neg Loss: 2.906887 | Pos Score: 5.013333 | Neg Score: -4.341130
# Epoch 148 | Step 040 | Loss: 2.925495 | Pos Loss: 0.019257 | Neg Loss: 2.906239 | Pos Score: 5.046277 | Neg Score: -4.446666
# Epoch 149 | Step 040 | Loss: 2.916642 | Pos Loss: 0.019079 | Neg Loss: 2.897562 | Pos Score: 5.055482 | Neg Score: -4.383495
# Epoch 150 | Step 040 | Loss: 2.904940 | Pos Loss: 0.018911 | Neg Loss: 2.886029 | Pos Score: 5.120190 | Neg Score: -4.396907
# Epoch 151 | Step 040 | Loss: 2.892326 | Pos Loss: 0.018839 | Neg Loss: 2.873488 | Pos Score: 5.131093 | Neg Score: -4.366024
# Epoch 152 | Step 040 | Loss: 2.871301 | Pos Loss: 0.018676 | Neg Loss: 2.852625 | Pos Score: 5.167525 | Neg Score: -4.550163
# Epoch 153 | Step 040 | Loss: 2.864925 | Pos Loss: 0.018576 | Neg Loss: 2.846348 | Pos Score: 5.159213 | Neg Score: -4.622570
# Epoch 154 | Step 040 | Loss: 2.867683 | Pos Loss: 0.018393 | Neg Loss: 2.849289 | Pos Score: 5.147070 | Neg Score: -4.501379
# Epoch 155 | Step 040 | Loss: 2.861351 | Pos Loss: 0.018304 | Neg Loss: 2.843047 | Pos Score: 5.145934 | Neg Score: -4.547401
# Epoch 156 | Step 040 | Loss: 2.857248 | Pos Loss: 0.018144 | Neg Loss: 2.839104 | Pos Score: 5.192972 | Neg Score: -4.457508
# Epoch 157 | Step 040 | Loss: 2.879051 | Pos Loss: 0.018019 | Neg Loss: 2.861032 | Pos Score: 5.181541 | Neg Score: -4.416878
# Epoch 158 | Step 040 | Loss: 2.843863 | Pos Loss: 0.017856 | Neg Loss: 2.826007 | Pos Score: 5.248993 | Neg Score: -4.665714
# Epoch 159 | Step 040 | Loss: 2.838828 | Pos Loss: 0.017765 | Neg Loss: 2.821063 | Pos Score: 5.269800 | Neg Score: -4.442436
# Epoch 160 | Step 040 | Loss: 2.832184 | Pos Loss: 0.017686 | Neg Loss: 2.814498 | Pos Score: 5.316324 | Neg Score: -4.610168
# Epoch 161 | Step 040 | Loss: 2.854794 | Pos Loss: 0.017661 | Neg Loss: 2.837133 | Pos Score: 5.318732 | Neg Score: -4.446808
# Epoch 162 | Step 040 | Loss: 2.825090 | Pos Loss: 0.017459 | Neg Loss: 2.807631 | Pos Score: 5.357908 | Neg Score: -4.486679
# Epoch 163 | Step 040 | Loss: 2.825319 | Pos Loss: 0.017310 | Neg Loss: 2.808009 | Pos Score: 5.317711 | Neg Score: -4.540323
# Epoch 164 | Step 040 | Loss: 2.819160 | Pos Loss: 0.017200 | Neg Loss: 2.801960 | Pos Score: 5.266274 | Neg Score: -4.529153
# Epoch 165 | Step 040 | Loss: 2.810381 | Pos Loss: 0.017108 | Neg Loss: 2.793273 | Pos Score: 5.304158 | Neg Score: -4.486464
# Epoch 166 | Step 040 | Loss: 2.802137 | Pos Loss: 0.017003 | Neg Loss: 2.785135 | Pos Score: 5.372283 | Neg Score: -4.638605
# Epoch 167 | Step 040 | Loss: 2.809521 | Pos Loss: 0.016848 | Neg Loss: 2.792673 | Pos Score: 5.372304 | Neg Score: -4.639150
# Epoch 168 | Step 040 | Loss: 2.806120 | Pos Loss: 0.016751 | Neg Loss: 2.789369 | Pos Score: 5.363701 | Neg Score: -4.577028
# Epoch 169 | Step 040 | Loss: 2.822185 | Pos Loss: 0.016573 | Neg Loss: 2.805612 | Pos Score: 5.403739 | Neg Score: -4.507116
# Epoch 170 | Step 040 | Loss: 2.776656 | Pos Loss: 0.016486 | Neg Loss: 2.760170 | Pos Score: 5.386419 | Neg Score: -4.575690
# Epoch 171 | Step 040 | Loss: 2.763637 | Pos Loss: 0.016415 | Neg Loss: 2.747222 | Pos Score: 5.366501 | Neg Score: -4.594759
# Epoch 172 | Step 040 | Loss: 2.819658 | Pos Loss: 0.016311 | Neg Loss: 2.803347 | Pos Score: 5.412489 | Neg Score: -4.496518
# Epoch 173 | Step 040 | Loss: 2.760787 | Pos Loss: 0.016103 | Neg Loss: 2.744684 | Pos Score: 5.408402 | Neg Score: -4.569503
# Epoch 174 | Step 040 | Loss: 2.772133 | Pos Loss: 0.016052 | Neg Loss: 2.756081 | Pos Score: 5.417767 | Neg Score: -4.759603
# Epoch 175 | Step 040 | Loss: 2.753639 | Pos Loss: 0.015931 | Neg Loss: 2.737709 | Pos Score: 5.417201 | Neg Score: -4.652044
# Epoch 176 | Step 040 | Loss: 2.774492 | Pos Loss: 0.015834 | Neg Loss: 2.758659 | Pos Score: 5.465205 | Neg Score: -4.496126
# Epoch 177 | Step 040 | Loss: 2.759469 | Pos Loss: 0.015810 | Neg Loss: 2.743659 | Pos Score: 5.519077 | Neg Score: -4.481731
# Epoch 178 | Step 040 | Loss: 2.740972 | Pos Loss: 0.015789 | Neg Loss: 2.725183 | Pos Score: 5.521101 | Neg Score: -4.787374
# Epoch 179 | Step 040 | Loss: 2.747577 | Pos Loss: 0.015652 | Neg Loss: 2.731925 | Pos Score: 5.488181 | Neg Score: -4.591024
# Epoch 180 | Step 040 | Loss: 2.757634 | Pos Loss: 0.015479 | Neg Loss: 2.742155 | Pos Score: 5.478964 | Neg Score: -4.612573
# Epoch 181 | Step 040 | Loss: 2.721914 | Pos Loss: 0.015375 | Neg Loss: 2.706538 | Pos Score: 5.464125 | Neg Score: -4.823387
# Epoch 182 | Step 040 | Loss: 2.726666 | Pos Loss: 0.015359 | Neg Loss: 2.711307 | Pos Score: 5.428682 | Neg Score: -4.653862
# Epoch 183 | Step 040 | Loss: 2.729074 | Pos Loss: 0.015257 | Neg Loss: 2.713818 | Pos Score: 5.394490 | Neg Score: -4.766905
# Epoch 184 | Step 040 | Loss: 2.708935 | Pos Loss: 0.015150 | Neg Loss: 2.693785 | Pos Score: 5.369658 | Neg Score: -4.722591
# Epoch 185 | Step 040 | Loss: 2.732337 | Pos Loss: 0.015072 | Neg Loss: 2.717265 | Pos Score: 5.393221 | Neg Score: -4.616523
# Epoch 186 | Step 040 | Loss: 2.723876 | Pos Loss: 0.014959 | Neg Loss: 2.708917 | Pos Score: 5.467803 | Neg Score: -4.608027
# Epoch 187 | Step 040 | Loss: 2.703792 | Pos Loss: 0.014854 | Neg Loss: 2.688938 | Pos Score: 5.460362 | Neg Score: -4.706695
# Epoch 188 | Step 040 | Loss: 2.720970 | Pos Loss: 0.014782 | Neg Loss: 2.706188 | Pos Score: 5.425362 | Neg Score: -4.693302
# Epoch 189 | Step 040 | Loss: 2.714867 | Pos Loss: 0.014705 | Neg Loss: 2.700162 | Pos Score: 5.494950 | Neg Score: -4.612319
# Epoch 190 | Step 040 | Loss: 2.709800 | Pos Loss: 0.014652 | Neg Loss: 2.695148 | Pos Score: 5.475893 | Neg Score: -4.712724
# Epoch 191 | Step 040 | Loss: 2.701172 | Pos Loss: 0.014555 | Neg Loss: 2.686617 | Pos Score: 5.471300 | Neg Score: -4.641487
# Epoch 192 | Step 040 | Loss: 2.689370 | Pos Loss: 0.014535 | Neg Loss: 2.674835 | Pos Score: 5.494081 | Neg Score: -4.857117
# Epoch 193 | Step 040 | Loss: 2.689066 | Pos Loss: 0.014469 | Neg Loss: 2.674597 | Pos Score: 5.508822 | Neg Score: -4.783395
# Epoch 194 | Step 040 | Loss: 2.691326 | Pos Loss: 0.014352 | Neg Loss: 2.676974 | Pos Score: 5.504882 | Neg Score: -4.803909
# Epoch 195 | Step 040 | Loss: 2.695163 | Pos Loss: 0.014262 | Neg Loss: 2.680900 | Pos Score: 5.503912 | Neg Score: -4.869071
# Epoch 196 | Step 040 | Loss: 2.678879 | Pos Loss: 0.014192 | Neg Loss: 2.664686 | Pos Score: 5.497659 | Neg Score: -4.852128
# Epoch 197 | Step 040 | Loss: 2.684017 | Pos Loss: 0.014123 | Neg Loss: 2.669894 | Pos Score: 5.537295 | Neg Score: -4.905341
# Epoch 198 | Step 040 | Loss: 2.648172 | Pos Loss: 0.014057 | Neg Loss: 2.634115 | Pos Score: 5.513103 | Neg Score: -4.945404
# Epoch 199 | Step 040 | Loss: 2.676237 | Pos Loss: 0.014058 | Neg Loss: 2.662179 | Pos Score: 5.486446 | Neg Score: -4.919858
# Epoch 200 | Step 040 | Loss: 2.653643 | Pos Loss: 0.013991 | Neg Loss: 2.639653 | Pos Score: 5.437429 | Neg Score: -5.062800
# Epoch 201 | Step 040 | Loss: 2.683032 | Pos Loss: 0.013856 | Neg Loss: 2.669175 | Pos Score: 5.457158 | Neg Score: -5.014734
# Epoch 202 | Step 040 | Loss: 2.663490 | Pos Loss: 0.013705 | Neg Loss: 2.649785 | Pos Score: 5.533995 | Neg Score: -4.999121
# Epoch 203 | Step 040 | Loss: 2.652134 | Pos Loss: 0.013658 | Neg Loss: 2.638476 | Pos Score: 5.588774 | Neg Score: -4.908147
# Epoch 204 | Step 040 | Loss: 2.656666 | Pos Loss: 0.013670 | Neg Loss: 2.642996 | Pos Score: 5.608437 | Neg Score: -4.831825
# Epoch 205 | Step 040 | Loss: 2.632925 | Pos Loss: 0.013576 | Neg Loss: 2.619349 | Pos Score: 5.632794 | Neg Score: -4.939257
# Epoch 206 | Step 040 | Loss: 2.649275 | Pos Loss: 0.013527 | Neg Loss: 2.635749 | Pos Score: 5.575492 | Neg Score: -4.972543
# Epoch 207 | Step 040 | Loss: 2.661987 | Pos Loss: 0.013486 | Neg Loss: 2.648501 | Pos Score: 5.532974 | Neg Score: -4.738861
# Epoch 208 | Step 040 | Loss: 2.647093 | Pos Loss: 0.013554 | Neg Loss: 2.633540 | Pos Score: 5.548861 | Neg Score: -4.785672
# Epoch 209 | Step 040 | Loss: 2.626397 | Pos Loss: 0.013357 | Neg Loss: 2.613040 | Pos Score: 5.534215 | Neg Score: -4.745938
# Epoch 210 | Step 040 | Loss: 2.652052 | Pos Loss: 0.013268 | Neg Loss: 2.638784 | Pos Score: 5.566854 | Neg Score: -4.863409
# Epoch 211 | Step 040 | Loss: 2.619927 | Pos Loss: 0.013226 | Neg Loss: 2.606701 | Pos Score: 5.594207 | Neg Score: -4.896534
# Epoch 212 | Step 040 | Loss: 2.641036 | Pos Loss: 0.013145 | Neg Loss: 2.627891 | Pos Score: 5.593991 | Neg Score: -4.830668
# Epoch 213 | Step 040 | Loss: 2.627352 | Pos Loss: 0.013046 | Neg Loss: 2.614306 | Pos Score: 5.611412 | Neg Score: -4.922173
# Epoch 214 | Step 040 | Loss: 2.617381 | Pos Loss: 0.013055 | Neg Loss: 2.604327 | Pos Score: 5.601084 | Neg Score: -4.814598
# Epoch 215 | Step 040 | Loss: 2.602345 | Pos Loss: 0.013012 | Neg Loss: 2.589334 | Pos Score: 5.583560 | Neg Score: -4.803804
# Epoch 216 | Step 040 | Loss: 2.616219 | Pos Loss: 0.012925 | Neg Loss: 2.603294 | Pos Score: 5.568906 | Neg Score: -4.964621
# Epoch 217 | Step 040 | Loss: 2.608948 | Pos Loss: 0.012827 | Neg Loss: 2.596120 | Pos Score: 5.570835 | Neg Score: -4.909685
# Epoch 218 | Step 040 | Loss: 2.622417 | Pos Loss: 0.012720 | Neg Loss: 2.609696 | Pos Score: 5.565075 | Neg Score: -4.807969
# Epoch 219 | Step 040 | Loss: 2.593421 | Pos Loss: 0.012659 | Neg Loss: 2.580762 | Pos Score: 5.620888 | Neg Score: -4.915971
# Epoch 220 | Step 040 | Loss: 2.620120 | Pos Loss: 0.012619 | Neg Loss: 2.607501 | Pos Score: 5.583461 | Neg Score: -4.853160
# Epoch 221 | Step 040 | Loss: 2.611325 | Pos Loss: 0.012528 | Neg Loss: 2.598798 | Pos Score: 5.591561 | Neg Score: -4.978529
# Epoch 222 | Step 040 | Loss: 2.588434 | Pos Loss: 0.012479 | Neg Loss: 2.575955 | Pos Score: 5.643837 | Neg Score: -5.136778
# Epoch 223 | Step 040 | Loss: 2.610992 | Pos Loss: 0.012482 | Neg Loss: 2.598510 | Pos Score: 5.630056 | Neg Score: -5.136700
# Epoch 224 | Step 040 | Loss: 2.586065 | Pos Loss: 0.012434 | Neg Loss: 2.573631 | Pos Score: 5.651568 | Neg Score: -5.093809
# Epoch 225 | Step 040 | Loss: 2.608323 | Pos Loss: 0.012431 | Neg Loss: 2.595892 | Pos Score: 5.663421 | Neg Score: -5.149781
# Epoch 226 | Step 040 | Loss: 2.607099 | Pos Loss: 0.012463 | Neg Loss: 2.594636 | Pos Score: 5.728176 | Neg Score: -4.945405
# Epoch 227 | Step 040 | Loss: 2.572653 | Pos Loss: 0.012265 | Neg Loss: 2.560388 | Pos Score: 5.737788 | Neg Score: -5.132473
# Epoch 228 | Step 040 | Loss: 2.584564 | Pos Loss: 0.012246 | Neg Loss: 2.572318 | Pos Score: 5.729068 | Neg Score: -4.974461
# Epoch 229 | Step 040 | Loss: 2.564557 | Pos Loss: 0.012257 | Neg Loss: 2.552301 | Pos Score: 5.794796 | Neg Score: -5.132467
# Epoch 230 | Step 040 | Loss: 2.567786 | Pos Loss: 0.012160 | Neg Loss: 2.555626 | Pos Score: 5.763968 | Neg Score: -5.225530
# Epoch 231 | Step 040 | Loss: 2.589943 | Pos Loss: 0.012100 | Neg Loss: 2.577843 | Pos Score: 5.814989 | Neg Score: -4.919943
# Epoch 232 | Step 040 | Loss: 2.593004 | Pos Loss: 0.011994 | Neg Loss: 2.581010 | Pos Score: 5.825409 | Neg Score: -4.929353
# Epoch 233 | Step 040 | Loss: 2.551380 | Pos Loss: 0.011939 | Neg Loss: 2.539441 | Pos Score: 5.839391 | Neg Score: -4.978845
# Epoch 234 | Step 040 | Loss: 2.541716 | Pos Loss: 0.011908 | Neg Loss: 2.529808 | Pos Score: 5.833322 | Neg Score: -4.993182
# Epoch 235 | Step 040 | Loss: 2.561836 | Pos Loss: 0.011893 | Neg Loss: 2.549943 | Pos Score: 5.858001 | Neg Score: -5.172801
# Epoch 236 | Step 040 | Loss: 2.568784 | Pos Loss: 0.011838 | Neg Loss: 2.556946 | Pos Score: 5.781226 | Neg Score: -5.023342
# Epoch 237 | Step 040 | Loss: 2.557086 | Pos Loss: 0.011790 | Neg Loss: 2.545297 | Pos Score: 5.803166 | Neg Score: -5.173753
# Epoch 238 | Step 040 | Loss: 2.551426 | Pos Loss: 0.011753 | Neg Loss: 2.539673 | Pos Score: 5.798207 | Neg Score: -5.125400
# Epoch 239 | Step 040 | Loss: 2.558171 | Pos Loss: 0.011682 | Neg Loss: 2.546489 | Pos Score: 5.844376 | Neg Score: -5.132824
# Epoch 240 | Step 040 | Loss: 2.538071 | Pos Loss: 0.011588 | Neg Loss: 2.526483 | Pos Score: 5.890625 | Neg Score: -5.299007
# Epoch 241 | Step 040 | Loss: 2.559566 | Pos Loss: 0.011609 | Neg Loss: 2.547958 | Pos Score: 5.864744 | Neg Score: -5.145932
# Epoch 242 | Step 040 | Loss: 2.546064 | Pos Loss: 0.011568 | Neg Loss: 2.534496 | Pos Score: 5.891513 | Neg Score: -5.036713
# Epoch 243 | Step 040 | Loss: 2.541806 | Pos Loss: 0.011517 | Neg Loss: 2.530289 | Pos Score: 6.022591 | Neg Score: -5.017799
# Epoch 244 | Step 040 | Loss: 2.546414 | Pos Loss: 0.011430 | Neg Loss: 2.534984 | Pos Score: 5.942705 | Neg Score: -4.967434
# Epoch 245 | Step 040 | Loss: 2.528011 | Pos Loss: 0.011360 | Neg Loss: 2.516651 | Pos Score: 5.969997 | Neg Score: -5.102535
# Epoch 246 | Step 040 | Loss: 2.526010 | Pos Loss: 0.011371 | Neg Loss: 2.514638 | Pos Score: 5.940006 | Neg Score: -5.164443
# Epoch 247 | Step 040 | Loss: 2.510379 | Pos Loss: 0.011423 | Neg Loss: 2.498955 | Pos Score: 5.944100 | Neg Score: -5.063286
# Epoch 248 | Step 040 | Loss: 2.528896 | Pos Loss: 0.011332 | Neg Loss: 2.517564 | Pos Score: 5.926753 | Neg Score: -5.138062
# Epoch 249 | Step 040 | Loss: 2.531251 | Pos Loss: 0.011258 | Neg Loss: 2.519993 | Pos Score: 5.936242 | Neg Score: -5.134211
# Epoch 250 | Step 040 | Loss: 2.543479 | Pos Loss: 0.011299 | Neg Loss: 2.532180 | Pos Score: 6.017505 | Neg Score: -5.030097
# Epoch 251 | Step 040 | Loss: 2.534798 | Pos Loss: 0.011205 | Neg Loss: 2.523592 | Pos Score: 6.031108 | Neg Score: -5.070449
# Epoch 252 | Step 040 | Loss: 2.530569 | Pos Loss: 0.011149 | Neg Loss: 2.519420 | Pos Score: 6.007984 | Neg Score: -4.914346
# Epoch 253 | Step 040 | Loss: 2.533019 | Pos Loss: 0.011144 | Neg Loss: 2.521874 | Pos Score: 6.008454 | Neg Score: -4.941734
# Epoch 254 | Step 040 | Loss: 2.520798 | Pos Loss: 0.011210 | Neg Loss: 2.509588 | Pos Score: 6.020533 | Neg Score: -5.068240
# Epoch 255 | Step 040 | Loss: 2.514682 | Pos Loss: 0.011074 | Neg Loss: 2.503608 | Pos Score: 5.941560 | Neg Score: -5.027059
# Epoch 256 | Step 040 | Loss: 2.510800 | Pos Loss: 0.010999 | Neg Loss: 2.499800 | Pos Score: 5.983137 | Neg Score: -5.197887
# Epoch 257 | Step 040 | Loss: 2.502262 | Pos Loss: 0.010997 | Neg Loss: 2.491266 | Pos Score: 5.949578 | Neg Score: -5.197611
# Epoch 258 | Step 040 | Loss: 2.530734 | Pos Loss: 0.010944 | Neg Loss: 2.519790 | Pos Score: 5.980619 | Neg Score: -5.062246
# Epoch 259 | Step 040 | Loss: 2.492805 | Pos Loss: 0.010905 | Neg Loss: 2.481900 | Pos Score: 6.034785 | Neg Score: -5.230148
# Epoch 260 | Step 040 | Loss: 2.510834 | Pos Loss: 0.010848 | Neg Loss: 2.499986 | Pos Score: 5.966794 | Neg Score: -5.261989
# Epoch 261 | Step 040 | Loss: 2.507683 | Pos Loss: 0.010797 | Neg Loss: 2.496887 | Pos Score: 5.968228 | Neg Score: -5.281368
# Epoch 262 | Step 040 | Loss: 2.505175 | Pos Loss: 0.010754 | Neg Loss: 2.494421 | Pos Score: 5.926028 | Neg Score: -5.144172
# Epoch 263 | Step 040 | Loss: 2.513858 | Pos Loss: 0.010774 | Neg Loss: 2.503084 | Pos Score: 5.937566 | Neg Score: -5.107864
# Epoch 264 | Step 040 | Loss: 2.481967 | Pos Loss: 0.010741 | Neg Loss: 2.471225 | Pos Score: 5.960663 | Neg Score: -5.236055
# Epoch 265 | Step 040 | Loss: 2.490050 | Pos Loss: 0.010655 | Neg Loss: 2.479395 | Pos Score: 5.927656 | Neg Score: -5.217198
# Epoch 266 | Step 040 | Loss: 2.494345 | Pos Loss: 0.010662 | Neg Loss: 2.483684 | Pos Score: 5.941508 | Neg Score: -5.281523
# Epoch 267 | Step 040 | Loss: 2.502284 | Pos Loss: 0.010626 | Neg Loss: 2.491658 | Pos Score: 5.877703 | Neg Score: -5.137072
# Epoch 268 | Step 040 | Loss: 2.486901 | Pos Loss: 0.010596 | Neg Loss: 2.476305 | Pos Score: 5.841944 | Neg Score: -5.051280
# Epoch 269 | Step 040 | Loss: 2.483384 | Pos Loss: 0.010534 | Neg Loss: 2.472850 | Pos Score: 5.856691 | Neg Score: -5.195323
# Epoch 270 | Step 040 | Loss: 2.480858 | Pos Loss: 0.010568 | Neg Loss: 2.470290 | Pos Score: 5.805923 | Neg Score: -5.133742
# Epoch 271 | Step 040 | Loss: 2.464565 | Pos Loss: 0.010587 | Neg Loss: 2.453978 | Pos Score: 5.826956 | Neg Score: -5.290929
# Epoch 272 | Step 040 | Loss: 2.465489 | Pos Loss: 0.010510 | Neg Loss: 2.454979 | Pos Score: 5.782753 | Neg Score: -5.189013
# Epoch 273 | Step 040 | Loss: 2.485039 | Pos Loss: 0.010499 | Neg Loss: 2.474540 | Pos Score: 5.791437 | Neg Score: -5.277515
# Epoch 274 | Step 040 | Loss: 2.479191 | Pos Loss: 0.010463 | Neg Loss: 2.468728 | Pos Score: 5.802545 | Neg Score: -5.283831
# Epoch 275 | Step 040 | Loss: 2.488708 | Pos Loss: 0.010376 | Neg Loss: 2.478332 | Pos Score: 5.713451 | Neg Score: -5.181850
# Epoch 276 | Step 040 | Loss: 2.464078 | Pos Loss: 0.010409 | Neg Loss: 2.453669 | Pos Score: 5.772969 | Neg Score: -5.271012
# Epoch 277 | Step 040 | Loss: 2.478695 | Pos Loss: 0.010330 | Neg Loss: 2.468365 | Pos Score: 5.784861 | Neg Score: -5.363825
# Epoch 278 | Step 040 | Loss: 2.473778 | Pos Loss: 0.010320 | Neg Loss: 2.463458 | Pos Score: 5.836704 | Neg Score: -5.342968
# Epoch 279 | Step 040 | Loss: 2.449687 | Pos Loss: 0.010266 | Neg Loss: 2.439422 | Pos Score: 5.843722 | Neg Score: -5.302125
# Epoch 280 | Step 040 | Loss: 2.464090 | Pos Loss: 0.010244 | Neg Loss: 2.453846 | Pos Score: 5.912652 | Neg Score: -5.204994
# Epoch 281 | Step 040 | Loss: 2.464791 | Pos Loss: 0.010261 | Neg Loss: 2.454530 | Pos Score: 5.942485 | Neg Score: -5.211021
# Epoch 282 | Step 040 | Loss: 2.461752 | Pos Loss: 0.010171 | Neg Loss: 2.451580 | Pos Score: 5.930450 | Neg Score: -5.104049
# Epoch 283 | Step 040 | Loss: 2.469097 | Pos Loss: 0.010113 | Neg Loss: 2.458984 | Pos Score: 5.946056 | Neg Score: -5.129169
# Epoch 284 | Step 040 | Loss: 2.464088 | Pos Loss: 0.010056 | Neg Loss: 2.454032 | Pos Score: 5.890933 | Neg Score: -5.382447
# Epoch 285 | Step 040 | Loss: 2.451914 | Pos Loss: 0.010005 | Neg Loss: 2.441909 | Pos Score: 5.835920 | Neg Score: -5.352586
# Epoch 286 | Step 040 | Loss: 2.451090 | Pos Loss: 0.009975 | Neg Loss: 2.441115 | Pos Score: 5.837861 | Neg Score: -5.339745
# Epoch 287 | Step 040 | Loss: 2.451371 | Pos Loss: 0.010017 | Neg Loss: 2.441354 | Pos Score: 5.849010 | Neg Score: -5.423854
# Epoch 288 | Step 040 | Loss: 2.457624 | Pos Loss: 0.010000 | Neg Loss: 2.447624 | Pos Score: 5.837943 | Neg Score: -5.262592
# Epoch 289 | Step 040 | Loss: 2.435238 | Pos Loss: 0.010001 | Neg Loss: 2.425237 | Pos Score: 5.903267 | Neg Score: -5.295869
# Epoch 290 | Step 040 | Loss: 2.444647 | Pos Loss: 0.010049 | Neg Loss: 2.434598 | Pos Score: 5.895189 | Neg Score: -5.280672
# Epoch 291 | Step 040 | Loss: 2.418689 | Pos Loss: 0.009887 | Neg Loss: 2.408803 | Pos Score: 5.907979 | Neg Score: -5.350646
# Epoch 292 | Step 040 | Loss: 2.439797 | Pos Loss: 0.009905 | Neg Loss: 2.429892 | Pos Score: 5.946627 | Neg Score: -5.476014
# Epoch 293 | Step 040 | Loss: 2.448302 | Pos Loss: 0.009843 | Neg Loss: 2.438459 | Pos Score: 5.973993 | Neg Score: -5.515881
# Epoch 294 | Step 040 | Loss: 2.466390 | Pos Loss: 0.009785 | Neg Loss: 2.456605 | Pos Score: 5.962655 | Neg Score: -5.272123
# Epoch 295 | Step 040 | Loss: 2.443480 | Pos Loss: 0.009844 | Neg Loss: 2.433637 | Pos Score: 6.020641 | Neg Score: -5.258499
# Epoch 296 | Step 040 | Loss: 2.429847 | Pos Loss: 0.009804 | Neg Loss: 2.420043 | Pos Score: 6.004933 | Neg Score: -5.435397
# Epoch 297 | Step 040 | Loss: 2.430784 | Pos Loss: 0.009852 | Neg Loss: 2.420933 | Pos Score: 6.015643 | Neg Score: -5.360577
# Epoch 298 | Step 040 | Loss: 2.414228 | Pos Loss: 0.009769 | Neg Loss: 2.404459 | Pos Score: 5.996494 | Neg Score: -5.475842
# Epoch 299 | Step 040 | Loss: 2.423227 | Pos Loss: 0.009710 | Neg Loss: 2.413517 | Pos Score: 6.043871 | Neg Score: -5.573692
# Epoch 300 | Step 040 | Loss: 2.431346 | Pos Loss: 0.009679 | Neg Loss: 2.421667 | Pos Score: 6.034113 | Neg Score: -5.437426
# Epoch 301 | Step 040 | Loss: 2.436688 | Pos Loss: 0.009730 | Neg Loss: 2.426958 | Pos Score: 6.001835 | Neg Score: -5.390954
# Epoch 302 | Step 040 | Loss: 2.432643 | Pos Loss: 0.009685 | Neg Loss: 2.422958 | Pos Score: 6.042980 | Neg Score: -5.354457
# Epoch 303 | Step 040 | Loss: 2.427816 | Pos Loss: 0.009690 | Neg Loss: 2.418126 | Pos Score: 6.072420 | Neg Score: -5.212221
# Epoch 304 | Step 040 | Loss: 2.418189 | Pos Loss: 0.009628 | Neg Loss: 2.408560 | Pos Score: 6.104460 | Neg Score: -5.317179
# Epoch 305 | Step 040 | Loss: 2.433725 | Pos Loss: 0.009595 | Neg Loss: 2.424130 | Pos Score: 6.160536 | Neg Score: -5.174306
# Epoch 306 | Step 040 | Loss: 2.416746 | Pos Loss: 0.009602 | Neg Loss: 2.407144 | Pos Score: 6.127187 | Neg Score: -5.296842
# Epoch 307 | Step 040 | Loss: 2.417587 | Pos Loss: 0.009618 | Neg Loss: 2.407969 | Pos Score: 6.106616 | Neg Score: -5.219006
# Epoch 308 | Step 040 | Loss: 2.427270 | Pos Loss: 0.009587 | Neg Loss: 2.417684 | Pos Score: 6.208023 | Neg Score: -5.213470
# Epoch 309 | Step 040 | Loss: 2.423220 | Pos Loss: 0.009518 | Neg Loss: 2.413702 | Pos Score: 6.115130 | Neg Score: -5.398254
# Epoch 310 | Step 040 | Loss: 2.423688 | Pos Loss: 0.009471 | Neg Loss: 2.414217 | Pos Score: 6.051753 | Neg Score: -5.470682
# Epoch 311 | Step 040 | Loss: 2.392997 | Pos Loss: 0.009450 | Neg Loss: 2.383547 | Pos Score: 6.020479 | Neg Score: -5.512119
# Epoch 312 | Step 040 | Loss: 2.422188 | Pos Loss: 0.009425 | Neg Loss: 2.412763 | Pos Score: 6.039200 | Neg Score: -5.334597
# Epoch 313 | Step 040 | Loss: 2.383440 | Pos Loss: 0.009469 | Neg Loss: 2.373971 | Pos Score: 6.139632 | Neg Score: -5.491027
# Epoch 314 | Step 040 | Loss: 2.410131 | Pos Loss: 0.009384 | Neg Loss: 2.400748 | Pos Score: 6.080156 | Neg Score: -5.507062
# Epoch 315 | Step 040 | Loss: 2.403557 | Pos Loss: 0.009511 | Neg Loss: 2.394047 | Pos Score: 6.095862 | Neg Score: -5.495169
# Epoch 316 | Step 040 | Loss: 2.408002 | Pos Loss: 0.009362 | Neg Loss: 2.398640 | Pos Score: 6.185682 | Neg Score: -5.448341
# Epoch 317 | Step 040 | Loss: 2.394811 | Pos Loss: 0.009431 | Neg Loss: 2.385379 | Pos Score: 6.120295 | Neg Score: -5.676409
# Epoch 318 | Step 040 | Loss: 2.390163 | Pos Loss: 0.009341 | Neg Loss: 2.380822 | Pos Score: 6.099154 | Neg Score: -5.574947
# Epoch 319 | Step 040 | Loss: 2.420805 | Pos Loss: 0.009343 | Neg Loss: 2.411462 | Pos Score: 6.064688 | Neg Score: -5.307966
# Epoch 320 | Step 040 | Loss: 2.418363 | Pos Loss: 0.009324 | Neg Loss: 2.409038 | Pos Score: 6.165844 | Neg Score: -5.201664
# Epoch 321 | Step 040 | Loss: 2.406743 | Pos Loss: 0.009261 | Neg Loss: 2.397483 | Pos Score: 6.144789 | Neg Score: -5.248497
# Epoch 322 | Step 040 | Loss: 2.405057 | Pos Loss: 0.009265 | Neg Loss: 2.395792 | Pos Score: 6.120671 | Neg Score: -5.526194
# Epoch 323 | Step 040 | Loss: 2.401188 | Pos Loss: 0.009258 | Neg Loss: 2.391930 | Pos Score: 6.065410 | Neg Score: -5.584435
# Epoch 324 | Step 040 | Loss: 2.374945 | Pos Loss: 0.009259 | Neg Loss: 2.365686 | Pos Score: 6.040504 | Neg Score: -5.542906
# Epoch 325 | Step 040 | Loss: 2.384172 | Pos Loss: 0.009167 | Neg Loss: 2.375004 | Pos Score: 6.062468 | Neg Score: -5.556919
# Epoch 326 | Step 040 | Loss: 2.410617 | Pos Loss: 0.009146 | Neg Loss: 2.401471 | Pos Score: 6.107370 | Neg Score: -5.279532
# Epoch 327 | Step 040 | Loss: 2.394210 | Pos Loss: 0.009114 | Neg Loss: 2.385095 | Pos Score: 6.168678 | Neg Score: -5.486512
# Epoch 328 | Step 040 | Loss: 2.420295 | Pos Loss: 0.009112 | Neg Loss: 2.411183 | Pos Score: 6.143605 | Neg Score: -5.485969
# Epoch 329 | Step 040 | Loss: 2.397370 | Pos Loss: 0.009139 | Neg Loss: 2.388232 | Pos Score: 6.133256 | Neg Score: -5.532796
# Epoch 330 | Step 040 | Loss: 2.391548 | Pos Loss: 0.009128 | Neg Loss: 2.382420 | Pos Score: 6.286149 | Neg Score: -5.499145
# Epoch 331 | Step 040 | Loss: 2.399305 | Pos Loss: 0.009057 | Neg Loss: 2.390247 | Pos Score: 6.216486 | Neg Score: -5.494686
# Epoch 332 | Step 040 | Loss: 2.378083 | Pos Loss: 0.009044 | Neg Loss: 2.369039 | Pos Score: 6.184503 | Neg Score: -5.616027
# Epoch 333 | Step 040 | Loss: 2.375808 | Pos Loss: 0.009051 | Neg Loss: 2.366756 | Pos Score: 6.189260 | Neg Score: -5.473167
# Epoch 334 | Step 040 | Loss: 2.373608 | Pos Loss: 0.009042 | Neg Loss: 2.364566 | Pos Score: 6.269966 | Neg Score: -5.389163
# Epoch 335 | Step 040 | Loss: 2.376183 | Pos Loss: 0.009055 | Neg Loss: 2.367129 | Pos Score: 6.282843 | Neg Score: -5.476306
# Epoch 336 | Step 040 | Loss: 2.391759 | Pos Loss: 0.008976 | Neg Loss: 2.382783 | Pos Score: 6.316669 | Neg Score: -5.472921
# Epoch 337 | Step 040 | Loss: 2.361168 | Pos Loss: 0.008936 | Neg Loss: 2.352232 | Pos Score: 6.319180 | Neg Score: -5.431159
# Epoch 338 | Step 040 | Loss: 2.378602 | Pos Loss: 0.008969 | Neg Loss: 2.369633 | Pos Score: 6.213457 | Neg Score: -5.352893
# Epoch 339 | Step 040 | Loss: 2.360660 | Pos Loss: 0.008956 | Neg Loss: 2.351704 | Pos Score: 6.176216 | Neg Score: -5.562314
# Epoch 340 | Step 040 | Loss: 2.385926 | Pos Loss: 0.008896 | Neg Loss: 2.377030 | Pos Score: 6.169205 | Neg Score: -5.482634
# Epoch 341 | Step 040 | Loss: 2.379544 | Pos Loss: 0.008996 | Neg Loss: 2.370547 | Pos Score: 6.152165 | Neg Score: -5.410974
# Epoch 342 | Step 040 | Loss: 2.379334 | Pos Loss: 0.008863 | Neg Loss: 2.370471 | Pos Score: 6.227392 | Neg Score: -5.308177
# Epoch 343 | Step 040 | Loss: 2.347566 | Pos Loss: 0.008927 | Neg Loss: 2.338640 | Pos Score: 6.217845 | Neg Score: -5.671098
# Epoch 344 | Step 040 | Loss: 2.348322 | Pos Loss: 0.008904 | Neg Loss: 2.339419 | Pos Score: 6.185668 | Neg Score: -5.769109
# Epoch 345 | Step 040 | Loss: 2.359415 | Pos Loss: 0.008857 | Neg Loss: 2.350558 | Pos Score: 6.181778 | Neg Score: -5.779585
# Epoch 346 | Step 040 | Loss: 2.358312 | Pos Loss: 0.008821 | Neg Loss: 2.349492 | Pos Score: 6.248733 | Neg Score: -5.625290
# Epoch 347 | Step 040 | Loss: 2.377746 | Pos Loss: 0.008784 | Neg Loss: 2.368963 | Pos Score: 6.222192 | Neg Score: -5.620547
# Epoch 348 | Step 040 | Loss: 2.367077 | Pos Loss: 0.008806 | Neg Loss: 2.358271 | Pos Score: 6.310690 | Neg Score: -5.496063
# Epoch 349 | Step 040 | Loss: 2.373196 | Pos Loss: 0.008963 | Neg Loss: 2.364233 | Pos Score: 6.310100 | Neg Score: -5.501946
# Epoch 350 | Step 040 | Loss: 2.341452 | Pos Loss: 0.008884 | Neg Loss: 2.332568 | Pos Score: 6.348098 | Neg Score: -5.341670
# Epoch 351 | Step 040 | Loss: 2.363138 | Pos Loss: 0.008774 | Neg Loss: 2.354364 | Pos Score: 6.297055 | Neg Score: -5.381650
# Epoch 352 | Step 040 | Loss: 2.347628 | Pos Loss: 0.008965 | Neg Loss: 2.338663 | Pos Score: 6.311050 | Neg Score: -5.500827
# Epoch 353 | Step 040 | Loss: 2.357738 | Pos Loss: 0.008722 | Neg Loss: 2.349016 | Pos Score: 6.182341 | Neg Score: -5.582342
# Epoch 354 | Step 040 | Loss: 2.356274 | Pos Loss: 0.008718 | Neg Loss: 2.347556 | Pos Score: 6.265156 | Neg Score: -5.588858
# Epoch 355 | Step 040 | Loss: 2.367007 | Pos Loss: 0.008775 | Neg Loss: 2.358231 | Pos Score: 6.234677 | Neg Score: -5.773900
# Epoch 356 | Step 040 | Loss: 2.331880 | Pos Loss: 0.008731 | Neg Loss: 2.323149 | Pos Score: 6.195471 | Neg Score: -5.846305
# Epoch 357 | Step 040 | Loss: 2.342087 | Pos Loss: 0.008757 | Neg Loss: 2.333330 | Pos Score: 6.196203 | Neg Score: -5.805840
# Epoch 358 | Step 040 | Loss: 2.344897 | Pos Loss: 0.008763 | Neg Loss: 2.336134 | Pos Score: 6.209436 | Neg Score: -5.844860
# Epoch 359 | Step 040 | Loss: 2.359531 | Pos Loss: 0.008716 | Neg Loss: 2.350815 | Pos Score: 6.213260 | Neg Score: -5.610952
# Epoch 360 | Step 040 | Loss: 2.360572 | Pos Loss: 0.008666 | Neg Loss: 2.351905 | Pos Score: 6.220335 | Neg Score: -5.601547
# Epoch 361 | Step 040 | Loss: 2.345849 | Pos Loss: 0.008676 | Neg Loss: 2.337174 | Pos Score: 6.237362 | Neg Score: -5.649451
# Epoch 362 | Step 040 | Loss: 2.333200 | Pos Loss: 0.008667 | Neg Loss: 2.324533 | Pos Score: 6.214636 | Neg Score: -5.798379
# Epoch 363 | Step 040 | Loss: 2.335118 | Pos Loss: 0.008707 | Neg Loss: 2.326411 | Pos Score: 6.260000 | Neg Score: -5.672410
# Epoch 364 | Step 040 | Loss: 2.336886 | Pos Loss: 0.008590 | Neg Loss: 2.328296 | Pos Score: 6.283193 | Neg Score: -5.825120
# Epoch 365 | Step 040 | Loss: 2.354109 | Pos Loss: 0.008588 | Neg Loss: 2.345521 | Pos Score: 6.262501 | Neg Score: -5.484140
# Epoch 366 | Step 040 | Loss: 2.355257 | Pos Loss: 0.008583 | Neg Loss: 2.346674 | Pos Score: 6.334004 | Neg Score: -5.531803
# Epoch 367 | Step 040 | Loss: 2.368454 | Pos Loss: 0.008581 | Neg Loss: 2.359873 | Pos Score: 6.294168 | Neg Score: -5.627817
# Epoch 368 | Step 040 | Loss: 2.341490 | Pos Loss: 0.008532 | Neg Loss: 2.332958 | Pos Score: 6.328711 | Neg Score: -5.447187
# Epoch 369 | Step 040 | Loss: 2.337698 | Pos Loss: 0.008616 | Neg Loss: 2.329083 | Pos Score: 6.267858 | Neg Score: -5.519695
# Epoch 370 | Step 040 | Loss: 2.334531 | Pos Loss: 0.008525 | Neg Loss: 2.326005 | Pos Score: 6.252691 | Neg Score: -5.640007
# Epoch 371 | Step 040 | Loss: 2.339018 | Pos Loss: 0.008561 | Neg Loss: 2.330457 | Pos Score: 6.207134 | Neg Score: -5.700885
# Epoch 372 | Step 040 | Loss: 2.332113 | Pos Loss: 0.008717 | Neg Loss: 2.323397 | Pos Score: 6.292031 | Neg Score: -5.782194
# Epoch 373 | Step 040 | Loss: 2.325287 | Pos Loss: 0.008689 | Neg Loss: 2.316598 | Pos Score: 6.258882 | Neg Score: -5.778132
# Epoch 374 | Step 040 | Loss: 2.306667 | Pos Loss: 0.008509 | Neg Loss: 2.298157 | Pos Score: 6.334333 | Neg Score: -5.838988
# Epoch 375 | Step 040 | Loss: 2.331381 | Pos Loss: 0.008519 | Neg Loss: 2.322862 | Pos Score: 6.303228 | Neg Score: -5.822864
# Epoch 376 | Step 040 | Loss: 2.339404 | Pos Loss: 0.008563 | Neg Loss: 2.330840 | Pos Score: 6.253391 | Neg Score: -5.759953
# Epoch 377 | Step 040 | Loss: 2.310186 | Pos Loss: 0.008564 | Neg Loss: 2.301622 | Pos Score: 6.254977 | Neg Score: -5.971041
# Epoch 378 | Step 040 | Loss: 2.329161 | Pos Loss: 0.008429 | Neg Loss: 2.320732 | Pos Score: 6.240662 | Neg Score: -5.868751
# Epoch 379 | Step 040 | Loss: 2.330572 | Pos Loss: 0.008540 | Neg Loss: 2.322031 | Pos Score: 6.312712 | Neg Score: -5.863553
# Epoch 380 | Step 040 | Loss: 2.327998 | Pos Loss: 0.008454 | Neg Loss: 2.319545 | Pos Score: 6.340198 | Neg Score: -5.718091
# Epoch 381 | Step 040 | Loss: 2.322452 | Pos Loss: 0.008601 | Neg Loss: 2.313851 | Pos Score: 6.419607 | Neg Score: -5.754448
# Epoch 382 | Step 040 | Loss: 2.321580 | Pos Loss: 0.008455 | Neg Loss: 2.313125 | Pos Score: 6.396772 | Neg Score: -5.622818
# Epoch 383 | Step 040 | Loss: 2.331478 | Pos Loss: 0.008365 | Neg Loss: 2.323113 | Pos Score: 6.455575 | Neg Score: -5.549747
# Epoch 384 | Step 040 | Loss: 2.325477 | Pos Loss: 0.008426 | Neg Loss: 2.317051 | Pos Score: 6.525435 | Neg Score: -5.522949
# ...
# Epoch 1875 | Step 040 | Loss: 1.992819 | Pos Loss: 0.007802 | Neg Loss: 1.985017 | Pos Score: 7.874605 | Neg Score: -8.080179
# Epoch 1876 | Step 040 | Loss: 2.003524 | Pos Loss: 0.008025 | Neg Loss: 1.995498 | Pos Score: 7.897789 | Neg Score: -8.571532
# Epoch 1877 | Step 040 | Loss: 1.977155 | Pos Loss: 0.008014 | Neg Loss: 1.969141 | Pos Score: 7.972088 | Neg Score: -8.380121
# Epoch 1878 | Step 040 | Loss: 1.996726 | Pos Loss: 0.008474 | Neg Loss: 1.988252 | Pos Score: 7.824708 | Neg Score: -8.705627
# Epoch 1879 | Step 040 | Loss: 1.997393 | Pos Loss: 0.007400 | Neg Loss: 1.989994 | Pos Score: 7.738824 | Neg Score: -8.781784
# Epoch 1880 | Step 040 | Loss: 1.998691 | Pos Loss: 0.007660 | Neg Loss: 1.991031 | Pos Score: 7.669322 | Neg Score: -8.559806
# Epoch 1881 | Step 040 | Loss: 1.992371 | Pos Loss: 0.009545 | Neg Loss: 1.982827 | Pos Score: 7.768694 | Neg Score: -8.610207
# Epoch 1882 | Step 040 | Loss: 1.979819 | Pos Loss: 0.007617 | Neg Loss: 1.972202 | Pos Score: 7.720482 | Neg Score: -8.688951
# Epoch 1883 | Step 040 | Loss: 1.986864 | Pos Loss: 0.007545 | Neg Loss: 1.979320 | Pos Score: 7.739709 | Neg Score: -8.691454
# Epoch 1884 | Step 040 | Loss: 2.018265 | Pos Loss: 0.007531 | Neg Loss: 2.010734 | Pos Score: 7.863772 | Neg Score: -8.392278
# Epoch 1885 | Step 040 | Loss: 2.014704 | Pos Loss: 0.007842 | Neg Loss: 2.006861 | Pos Score: 7.959060 | Neg Score: -8.102309
# Epoch 1886 | Step 040 | Loss: 1.995884 | Pos Loss: 0.007350 | Neg Loss: 1.988535 | Pos Score: 7.989642 | Neg Score: -8.630378
# Epoch 1887 | Step 040 | Loss: 1.985611 | Pos Loss: 0.007898 | Neg Loss: 1.977713 | Pos Score: 8.004157 | Neg Score: -8.352418
# Epoch 1888 | Step 040 | Loss: 1.991587 | Pos Loss: 0.007544 | Neg Loss: 1.984043 | Pos Score: 8.005379 | Neg Score: -8.094392
# Epoch 1889 | Step 040 | Loss: 2.014830 | Pos Loss: 0.007368 | Neg Loss: 2.007462 | Pos Score: 7.901258 | Neg Score: -8.666554
# Epoch 1890 | Step 040 | Loss: 1.993980 | Pos Loss: 0.008264 | Neg Loss: 1.985715 | Pos Score: 7.978583 | Neg Score: -8.240089
# Epoch 1891 | Step 040 | Loss: 2.006020 | Pos Loss: 0.008498 | Neg Loss: 1.997522 | Pos Score: 7.976700 | Neg Score: -8.438042
# Epoch 1892 | Step 040 | Loss: 1.990285 | Pos Loss: 0.007860 | Neg Loss: 1.982425 | Pos Score: 7.913629 | Neg Score: -8.455756
# Epoch 1893 | Step 040 | Loss: 2.011192 | Pos Loss: 0.007825 | Neg Loss: 2.003367 | Pos Score: 7.919285 | Neg Score: -8.403670
# Epoch 1894 | Step 040 | Loss: 1.981682 | Pos Loss: 0.007949 | Neg Loss: 1.973733 | Pos Score: 8.072004 | Neg Score: -8.080358
# Epoch 1895 | Step 040 | Loss: 1.973324 | Pos Loss: 0.006847 | Neg Loss: 1.966477 | Pos Score: 7.939688 | Neg Score: -8.536118
# Epoch 1896 | Step 040 | Loss: 1.973668 | Pos Loss: 0.007414 | Neg Loss: 1.966255 | Pos Score: 7.910509 | Neg Score: -8.295505
# Epoch 1897 | Step 040 | Loss: 1.970664 | Pos Loss: 0.008702 | Neg Loss: 1.961963 | Pos Score: 8.006573 | Neg Score: -8.285027
# Epoch 1898 | Step 040 | Loss: 1.997112 | Pos Loss: 0.007713 | Neg Loss: 1.989399 | Pos Score: 8.018965 | Neg Score: -8.211188
# Epoch 1899 | Step 040 | Loss: 2.028234 | Pos Loss: 0.007731 | Neg Loss: 2.020503 | Pos Score: 7.897930 | Neg Score: -8.052678
# Epoch 1900 | Step 040 | Loss: 2.004815 | Pos Loss: 0.008356 | Neg Loss: 1.996459 | Pos Score: 8.020705 | Neg Score: -8.173684
# Epoch 1901 | Step 040 | Loss: 1.977333 | Pos Loss: 0.007782 | Neg Loss: 1.969551 | Pos Score: 7.922382 | Neg Score: -8.293700
# Epoch 1902 | Step 040 | Loss: 1.994668 | Pos Loss: 0.008790 | Neg Loss: 1.985878 | Pos Score: 7.872390 | Neg Score: -8.394018
# Epoch 1903 | Step 040 | Loss: 1.997943 | Pos Loss: 0.007160 | Neg Loss: 1.990783 | Pos Score: 7.848999 | Neg Score: -8.464081
# Epoch 1904 | Step 040 | Loss: 1.985930 | Pos Loss: 0.008926 | Neg Loss: 1.977004 | Pos Score: 7.895402 | Neg Score: -8.422711
# Epoch 1905 | Step 040 | Loss: 1.990891 | Pos Loss: 0.008837 | Neg Loss: 1.982053 | Pos Score: 7.862404 | Neg Score: -8.031397
# Epoch 1906 | Step 040 | Loss: 2.002713 | Pos Loss: 0.008996 | Neg Loss: 1.993717 | Pos Score: 7.909376 | Neg Score: -8.118196
# Epoch 1907 | Step 040 | Loss: 1.996410 | Pos Loss: 0.008729 | Neg Loss: 1.987681 | Pos Score: 7.834396 | Neg Score: -8.032790
# Epoch 1908 | Step 040 | Loss: 1.989090 | Pos Loss: 0.007985 | Neg Loss: 1.981105 | Pos Score: 7.679007 | Neg Score: -8.601395
# Epoch 1909 | Step 040 | Loss: 2.009858 | Pos Loss: 0.008154 | Neg Loss: 2.001704 | Pos Score: 7.781764 | Neg Score: -8.480060
# Epoch 1910 | Step 040 | Loss: 1.990608 | Pos Loss: 0.009186 | Neg Loss: 1.981422 | Pos Score: 7.649823 | Neg Score: -8.582766
# Epoch 1911 | Step 040 | Loss: 2.001743 | Pos Loss: 0.007432 | Neg Loss: 1.994311 | Pos Score: 8.044691 | Neg Score: -8.147506
# Epoch 1912 | Step 040 | Loss: 2.007342 | Pos Loss: 0.008539 | Neg Loss: 1.998803 | Pos Score: 8.046635 | Neg Score: -8.573230
# Epoch 1913 | Step 040 | Loss: 2.020458 | Pos Loss: 0.008521 | Neg Loss: 2.011937 | Pos Score: 8.054800 | Neg Score: -8.241835
# Epoch 1914 | Step 040 | Loss: 1.977645 | Pos Loss: 0.008992 | Neg Loss: 1.968653 | Pos Score: 8.248572 | Neg Score: -8.101562
# Epoch 1915 | Step 040 | Loss: 1.991936 | Pos Loss: 0.007333 | Neg Loss: 1.984603 | Pos Score: 8.178082 | Neg Score: -8.007270
# Epoch 1916 | Step 040 | Loss: 1.991985 | Pos Loss: 0.007153 | Neg Loss: 1.984832 | Pos Score: 7.947158 | Neg Score: -8.312180
# Epoch 1917 | Step 040 | Loss: 1.992663 | Pos Loss: 0.007525 | Neg Loss: 1.985138 | Pos Score: 7.952184 | Neg Score: -8.561320
# Epoch 1918 | Step 040 | Loss: 1.998831 | Pos Loss: 0.008205 | Neg Loss: 1.990626 | Pos Score: 7.968189 | Neg Score: -8.289375
# Epoch 1919 | Step 040 | Loss: 2.005101 | Pos Loss: 0.007854 | Neg Loss: 1.997247 | Pos Score: 8.160315 | Neg Score: -8.043845
# Epoch 1920 | Step 040 | Loss: 2.007397 | Pos Loss: 0.008318 | Neg Loss: 1.999079 | Pos Score: 7.985270 | Neg Score: -8.330447
# Epoch 1921 | Step 040 | Loss: 2.014471 | Pos Loss: 0.008288 | Neg Loss: 2.006183 | Pos Score: 8.125484 | Neg Score: -8.342537
# Epoch 1922 | Step 040 | Loss: 1.972765 | Pos Loss: 0.008618 | Neg Loss: 1.964147 | Pos Score: 8.080018 | Neg Score: -8.422005
# Epoch 1923 | Step 040 | Loss: 1.979005 | Pos Loss: 0.008026 | Neg Loss: 1.970980 | Pos Score: 7.937210 | Neg Score: -8.738465
# Epoch 1924 | Step 040 | Loss: 1.996365 | Pos Loss: 0.007562 | Neg Loss: 1.988803 | Pos Score: 7.817779 | Neg Score: -9.089037
# Epoch 1925 | Step 040 | Loss: 1.986483 | Pos Loss: 0.008300 | Neg Loss: 1.978183 | Pos Score: 7.930515 | Neg Score: -8.832252
# Epoch 1926 | Step 040 | Loss: 2.001137 | Pos Loss: 0.007363 | Neg Loss: 1.993774 | Pos Score: 8.004841 | Neg Score: -8.679576
# Epoch 1927 | Step 040 | Loss: 2.013300 | Pos Loss: 0.007904 | Neg Loss: 2.005397 | Pos Score: 7.818480 | Neg Score: -8.760884
# Epoch 1928 | Step 040 | Loss: 1.997259 | Pos Loss: 0.009424 | Neg Loss: 1.987835 | Pos Score: 7.830480 | Neg Score: -8.604133
# Epoch 1929 | Step 040 | Loss: 1.972889 | Pos Loss: 0.007525 | Neg Loss: 1.965364 | Pos Score: 7.869033 | Neg Score: -8.418973
# Epoch 1930 | Step 040 | Loss: 1.998300 | Pos Loss: 0.008895 | Neg Loss: 1.989406 | Pos Score: 7.506047 | Neg Score: -9.105066
# Epoch 1931 | Step 040 | Loss: 1.999921 | Pos Loss: 0.008225 | Neg Loss: 1.991696 | Pos Score: 7.708323 | Neg Score: -8.803200
# Epoch 1932 | Step 040 | Loss: 1.988390 | Pos Loss: 0.007748 | Neg Loss: 1.980642 | Pos Score: 7.726455 | Neg Score: -8.785864
# Epoch 1933 | Step 040 | Loss: 1.994558 | Pos Loss: 0.008122 | Neg Loss: 1.986436 | Pos Score: 7.865836 | Neg Score: -8.720860
# Epoch 1934 | Step 040 | Loss: 1.998505 | Pos Loss: 0.008029 | Neg Loss: 1.990476 | Pos Score: 7.854697 | Neg Score: -8.482859
# Epoch 1935 | Step 040 | Loss: 2.013418 | Pos Loss: 0.008530 | Neg Loss: 2.004888 | Pos Score: 7.880901 | Neg Score: -8.772541
# Epoch 1936 | Step 040 | Loss: 1.994477 | Pos Loss: 0.008450 | Neg Loss: 1.986027 | Pos Score: 7.924010 | Neg Score: -8.451957
# Epoch 1937 | Step 040 | Loss: 2.010684 | Pos Loss: 0.008595 | Neg Loss: 2.002089 | Pos Score: 7.860311 | Neg Score: -8.380391
# Epoch 1938 | Step 040 | Loss: 1.985133 | Pos Loss: 0.008019 | Neg Loss: 1.977114 | Pos Score: 7.788882 | Neg Score: -8.366480
# Epoch 1939 | Step 040 | Loss: 1.994223 | Pos Loss: 0.009553 | Neg Loss: 1.984670 | Pos Score: 7.864224 | Neg Score: -8.672467
# Epoch 1940 | Step 040 | Loss: 1.994223 | Pos Loss: 0.008819 | Neg Loss: 1.985404 | Pos Score: 8.039126 | Neg Score: -8.639766
# Epoch 1941 | Step 040 | Loss: 1.984740 | Pos Loss: 0.009220 | Neg Loss: 1.975520 | Pos Score: 8.203387 | Neg Score: -8.558566
# Epoch 1942 | Step 040 | Loss: 1.990030 | Pos Loss: 0.009298 | Neg Loss: 1.980732 | Pos Score: 8.233117 | Neg Score: -8.289003
# Epoch 1943 | Step 040 | Loss: 1.978100 | Pos Loss: 0.008930 | Neg Loss: 1.969170 | Pos Score: 8.253368 | Neg Score: -8.390999
# Epoch 1944 | Step 040 | Loss: 1.978928 | Pos Loss: 0.008006 | Neg Loss: 1.970922 | Pos Score: 8.078343 | Neg Score: -8.116544
# Epoch 1945 | Step 040 | Loss: 2.003133 | Pos Loss: 0.007626 | Neg Loss: 1.995507 | Pos Score: 8.110545 | Neg Score: -8.083405
# Epoch 1946 | Step 040 | Loss: 1.995433 | Pos Loss: 0.007750 | Neg Loss: 1.987683 | Pos Score: 8.092905 | Neg Score: -8.274337
# Epoch 1947 | Step 040 | Loss: 2.011086 | Pos Loss: 0.008094 | Neg Loss: 2.002992 | Pos Score: 8.075399 | Neg Score: -8.471848
# Epoch 1948 | Step 040 | Loss: 2.001663 | Pos Loss: 0.008189 | Neg Loss: 1.993475 | Pos Score: 8.098492 | Neg Score: -8.315703
# Epoch 1949 | Step 040 | Loss: 1.998070 | Pos Loss: 0.007838 | Neg Loss: 1.990232 | Pos Score: 8.091972 | Neg Score: -8.162902
# Epoch 1950 | Step 040 | Loss: 2.005065 | Pos Loss: 0.007956 | Neg Loss: 1.997109 | Pos Score: 7.941955 | Neg Score: -8.353800
# Epoch 1951 | Step 040 | Loss: 1.996957 | Pos Loss: 0.007812 | Neg Loss: 1.989145 | Pos Score: 7.967798 | Neg Score: -8.310581
# Epoch 1952 | Step 040 | Loss: 1.994421 | Pos Loss: 0.008398 | Neg Loss: 1.986022 | Pos Score: 7.923428 | Neg Score: -8.429404
# Epoch 1953 | Step 040 | Loss: 1.992375 | Pos Loss: 0.008211 | Neg Loss: 1.984164 | Pos Score: 7.858604 | Neg Score: -8.082590
# Epoch 1954 | Step 040 | Loss: 1.987422 | Pos Loss: 0.009359 | Neg Loss: 1.978063 | Pos Score: 7.501387 | Neg Score: -8.904965
# Epoch 1955 | Step 040 | Loss: 2.005971 | Pos Loss: 0.008025 | Neg Loss: 1.997946 | Pos Score: 7.899109 | Neg Score: -8.298174
# Epoch 1956 | Step 040 | Loss: 1.983455 | Pos Loss: 0.007502 | Neg Loss: 1.975953 | Pos Score: 8.039886 | Neg Score: -8.082518
# Epoch 1957 | Step 040 | Loss: 2.006317 | Pos Loss: 0.008306 | Neg Loss: 1.998011 | Pos Score: 8.157840 | Neg Score: -8.097423
# Epoch 1958 | Step 040 | Loss: 2.007934 | Pos Loss: 0.008368 | Neg Loss: 1.999567 | Pos Score: 8.126099 | Neg Score: -8.184979
# Epoch 1959 | Step 040 | Loss: 1.973115 | Pos Loss: 0.008307 | Neg Loss: 1.964807 | Pos Score: 8.193642 | Neg Score: -8.037644
# Epoch 1960 | Step 040 | Loss: 1.998430 | Pos Loss: 0.007756 | Neg Loss: 1.990674 | Pos Score: 8.078759 | Neg Score: -8.199018
# Epoch 1961 | Step 040 | Loss: 1.983250 | Pos Loss: 0.007907 | Neg Loss: 1.975343 | Pos Score: 7.942147 | Neg Score: -8.404912
# Epoch 1962 | Step 040 | Loss: 2.007150 | Pos Loss: 0.007378 | Neg Loss: 1.999772 | Pos Score: 7.988705 | Neg Score: -8.363045
# Epoch 1963 | Step 040 | Loss: 1.991244 | Pos Loss: 0.008236 | Neg Loss: 1.983008 | Pos Score: 8.024632 | Neg Score: -8.280963
# Epoch 1964 | Step 040 | Loss: 2.001299 | Pos Loss: 0.008253 | Neg Loss: 1.993046 | Pos Score: 7.838793 | Neg Score: -8.608027
# Epoch 1965 | Step 040 | Loss: 1.972953 | Pos Loss: 0.007644 | Neg Loss: 1.965309 | Pos Score: 7.736584 | Neg Score: -8.446877
# Epoch 1966 | Step 040 | Loss: 1.983911 | Pos Loss: 0.007736 | Neg Loss: 1.976175 | Pos Score: 7.764969 | Neg Score: -8.540127
# Epoch 1967 | Step 040 | Loss: 2.005997 | Pos Loss: 0.008858 | Neg Loss: 1.997140 | Pos Score: 7.861466 | Neg Score: -8.227603
# Epoch 1968 | Step 040 | Loss: 2.010477 | Pos Loss: 0.007608 | Neg Loss: 2.002869 | Pos Score: 7.980662 | Neg Score: -8.537078
# Epoch 1969 | Step 040 | Loss: 2.002817 | Pos Loss: 0.007888 | Neg Loss: 1.994930 | Pos Score: 8.046028 | Neg Score: -8.064707
# Epoch 1970 | Step 040 | Loss: 2.007462 | Pos Loss: 0.007051 | Neg Loss: 2.000410 | Pos Score: 8.100203 | Neg Score: -8.192571
# Epoch 1971 | Step 040 | Loss: 1.996594 | Pos Loss: 0.008052 | Neg Loss: 1.988542 | Pos Score: 8.154300 | Neg Score: -8.042362
# Epoch 1972 | Step 040 | Loss: 1.982959 | Pos Loss: 0.008497 | Neg Loss: 1.974461 | Pos Score: 8.039367 | Neg Score: -8.547516
# Epoch 1973 | Step 040 | Loss: 2.005308 | Pos Loss: 0.008195 | Neg Loss: 1.997114 | Pos Score: 7.989587 | Neg Score: -8.107301
# Epoch 1974 | Step 040 | Loss: 1.991369 | Pos Loss: 0.007722 | Neg Loss: 1.983646 | Pos Score: 7.996789 | Neg Score: -8.249430
# Epoch 1975 | Step 040 | Loss: 2.001173 | Pos Loss: 0.007926 | Neg Loss: 1.993247 | Pos Score: 7.902893 | Neg Score: -8.482165
# Epoch 1976 | Step 040 | Loss: 1.972698 | Pos Loss: 0.007745 | Neg Loss: 1.964953 | Pos Score: 7.902072 | Neg Score: -8.557495
# Epoch 1977 | Step 040 | Loss: 2.000834 | Pos Loss: 0.008033 | Neg Loss: 1.992801 | Pos Score: 8.026737 | Neg Score: -8.438667
# Epoch 1978 | Step 040 | Loss: 2.006891 | Pos Loss: 0.007330 | Neg Loss: 1.999561 | Pos Score: 7.882582 | Neg Score: -8.079325
# Epoch 1979 | Step 040 | Loss: 1.999830 | Pos Loss: 0.008385 | Neg Loss: 1.991445 | Pos Score: 8.053624 | Neg Score: -8.054149
# Epoch 1980 | Step 040 | Loss: 1.993447 | Pos Loss: 0.008560 | Neg Loss: 1.984887 | Pos Score: 8.066023 | Neg Score: -8.116712
# Epoch 1981 | Step 040 | Loss: 1.985198 | Pos Loss: 0.008576 | Neg Loss: 1.976622 | Pos Score: 8.050261 | Neg Score: -8.013667
# Epoch 1982 | Step 040 | Loss: 1.991638 | Pos Loss: 0.009775 | Neg Loss: 1.981863 | Pos Score: 7.917973 | Neg Score: -8.246287
# Epoch 1983 | Step 040 | Loss: 1.984696 | Pos Loss: 0.008512 | Neg Loss: 1.976184 | Pos Score: 8.046854 | Neg Score: -7.989344
# Epoch 1984 | Step 040 | Loss: 1.990399 | Pos Loss: 0.007970 | Neg Loss: 1.982429 | Pos Score: 8.010378 | Neg Score: -8.272023
# Epoch 1985 | Step 040 | Loss: 1.997363 | Pos Loss: 0.008221 | Neg Loss: 1.989141 | Pos Score: 8.017678 | Neg Score: -8.110248
# Epoch 1986 | Step 040 | Loss: 1.969905 | Pos Loss: 0.007959 | Neg Loss: 1.961946 | Pos Score: 8.017859 | Neg Score: -8.212726
# Epoch 1987 | Step 040 | Loss: 1.993736 | Pos Loss: 0.008516 | Neg Loss: 1.985221 | Pos Score: 7.691779 | Neg Score: -8.962766
# Epoch 1988 | Step 040 | Loss: 2.007438 | Pos Loss: 0.007768 | Neg Loss: 1.999670 | Pos Score: 7.807777 | Neg Score: -8.662354
# Epoch 1989 | Step 040 | Loss: 1.991460 | Pos Loss: 0.008741 | Neg Loss: 1.982719 | Pos Score: 7.880405 | Neg Score: -8.517902
# Epoch 1990 | Step 040 | Loss: 2.017582 | Pos Loss: 0.008693 | Neg Loss: 2.008889 | Pos Score: 7.892393 | Neg Score: -8.267220
# Epoch 1991 | Step 040 | Loss: 1.989433 | Pos Loss: 0.008122 | Neg Loss: 1.981311 | Pos Score: 7.949426 | Neg Score: -8.252052
# Epoch 1992 | Step 040 | Loss: 1.986023 | Pos Loss: 0.008093 | Neg Loss: 1.977931 | Pos Score: 8.045561 | Neg Score: -8.210709
# Epoch 1993 | Step 040 | Loss: 2.014113 | Pos Loss: 0.008558 | Neg Loss: 2.005555 | Pos Score: 8.029579 | Neg Score: -8.057188
# Epoch 1994 | Step 040 | Loss: 2.008534 | Pos Loss: 0.007597 | Neg Loss: 2.000937 | Pos Score: 7.874116 | Neg Score: -8.138596
# Epoch 1995 | Step 040 | Loss: 2.009617 | Pos Loss: 0.007951 | Neg Loss: 2.001666 | Pos Score: 7.740003 | Neg Score: -8.514916
# Epoch 1996 | Step 040 | Loss: 1.997845 | Pos Loss: 0.008093 | Neg Loss: 1.989752 | Pos Score: 7.916094 | Neg Score: -8.553914
# Epoch 1997 | Step 040 | Loss: 1.985089 | Pos Loss: 0.008265 | Neg Loss: 1.976824 | Pos Score: 7.701731 | Neg Score: -8.535978
# Epoch 1998 | Step 040 | Loss: 1.986883 | Pos Loss: 0.007766 | Neg Loss: 1.979117 | Pos Score: 7.806301 | Neg Score: -8.699824
# Epoch 1999 | Step 040 | Loss: 2.002708 | Pos Loss: 0.008732 | Neg Loss: 1.993976 | Pos Score: 7.862875 | Neg Score: -8.628217
# Epoch 2000 | Step 040 | Loss: 1.979039 | Pos Loss: 0.009371 | Neg Loss: 1.969668 | Pos Score: 7.916657 | Neg Score: -8.626034

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(12, 8))

loss = [h["running_loss"] for h in history]
pos_loss = [h["pos_loss_mean"] for h in history]
neg_loss = [h["neg_loss_mean"] for h in history]
poss_score = [h["pos_score_mean"].detach().cpu() for h in history]
neg_score = [h["neg_score_mean"].detach().cpu() for h in history]

ax1.plot(range(1, num_epochs + 1), loss, label="Total Loss")
ax2.plot(range(1, num_epochs + 1), pos_loss, label="Positive Loss")
ax3.plot(range(1, num_epochs + 1), neg_loss, label="Negative Loss")
ax4.plot(range(1, num_epochs + 1), poss_score, label="Positive Score")
ax5.plot(range(1, num_epochs + 1), neg_score, label="Negative Score")
ax6.axis("off")

ax1.set_title("Total Loss")
ax2.set_title("Positive Loss")
ax3.set_title("Negative Loss")
ax4.set_title("Positive Score")
ax5.set_title("Negative Score")
# Out:
# Text(0.5, 1.0, 'Negative Score')

# %%
emb = model.get_peak_embeddings(normalize=False).numpy()
np.save(f"data/peak2vec_epoch_{embedding_dim}_{num_epochs}_{trans_fraction}_{same_chr_negative_prob}.npy", emb)

emb = model.get_peak_embeddings(normalize=True).numpy()
np.save(f"data/peak2vec_epoch_norm_{embedding_dim}_{num_epochs}_{trans_fraction}_{same_chr_negative_prob}.npy", emb)

# %%
torch.save(model, f'data/peak2vec_model_{embedding_dim}_{num_epochs}_{trans_fraction}_{same_chr_negative_prob}.pth')

# %% [markdown]
# ## Visualize

# %% [markdown]
# ### Peaks

# %%
# adata_peaks = adata.transpose().copy()
adata_peaks.obsm["peak2vec"] = emb
adata_peaks
# Out:
# AnnData object with n_obs × n_vars = 264916 × 10126
#     obs: 'Chromosome', 'Start', 'End', 'Width', 'cisTopic_nr_frag', 'cisTopic_log_nr_frag', 'cisTopic_nr_acc', 'cisTopic_log_nr_acc', 'n_cells_per_feature', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'leiden'
#     var: 'cisTopic_nr_frag', 'cisTopic_log_nr_frag', 'cisTopic_nr_acc', 'cisTopic_log_nr_acc', 'sample_id', 'barcode_rank', 'total_fragments_count', 'log10_total_fragments_count', 'unique_fragments_count', 'log10_unique_fragments_count', 'total_fragments_in_peaks_count', 'log10_total_fragments_in_peaks_count', 'unique_fragments_in_peaks_count', 'log10_unique_fragments_in_peaks_count', 'fraction_of_fragments_in_peaks', 'duplication_count', 'duplication_ratio', 'nucleosome_signal', 'tss_enrichment', 'pdf_values_for_tss_enrichment', 'pdf_values_for_fraction_of_fragments_in_peaks', 'pdf_values_for_duplication_ratio', 'barcode', 'n_features_per_cell', 'total_fragment_counts', 'leiden'
#     uns: 'Chromosome_colors', 'leiden', 'leiden_colors', 'lsi', 'neighbors', 'umap'
#     obsm: 'LSI', 'X_umap', 'peak2vec'
#     varm: 'X_lsi', 'X_umap'
#     layers: 'binary', 'counts'
#     obsp: 'connectivities', 'distances'
#     varp: 'connectivities', 'distances'

# %%
# Find neighbors
sc.pp.neighbors(adata_peaks, use_rep="peak2vec", n_neighbors=15, n_pcs=50, metric="cosine")

# Calculate clusters
# sc.tl.leiden(adata_peaks, flavor="igraph", n_iterations=2)

# Calculate UMAP
sc.tl.umap(adata_peaks, random_state=4)

# %%
sc.pl.umap(
    adata_peaks,
    color=["Chromosome"],
    ncols=1,
    legend_loc="on data"
)

# %%
adata_peaks.obsm["X_pca"] = sc.pp.pca(emb, n_comps=50)
sc.pl.pca(adata_peaks, color=["Chromosome", "leiden"], ncols=1)

# %%
sc.pl.embedding(adata_peaks, basis="peak2vec", color=["Chromosome"])

# %% [markdown]
# ### Cells

# %%
adata.obsm["peak2vec"] = adata.X @ emb
adata.obsm["peak2vec"] = adata.obsm["peak2vec"] / (np.linalg.norm(adata.obsm["peak2vec"], axis=1, keepdims=True) + 1e-8)
# Find neighbors
sc.pp.neighbors(adata, use_rep="peak2vec", n_neighbors=15, n_pcs=30)

# Calculate UMAP
sc.tl.umap(adata, random_state=4)

# %%
sc.pl.embedding(adata, basis="peak2vec", color=["leiden"], save="_peak2vec.png")
# Out:
# WARNING: saving figure to file figures\peak2vec_peak2vec.png

# %%
sc.pl.umap(adata, color=["leiden"], save="_peak2vec_umap.png")
# Out:
# WARNING: saving figure to file figures\umap_peak2vec_umap.png

# %% [markdown]
# ## More training

# %%
#model = torch.load(f'data/peak2vec_model_128_200_1_0.pth', weights_only=False)

# %%
seed = 4
n_pairs = 20
n_negative = 10
samples_per_epoch = 20000
batch_size = 512
embedding_dim = 128
trans_fraction=0.2
cis_window=500000
same_chr_negative_prob=0.6
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)
# Out:
# Using device: cuda

# %%
dataset = PeakDataset(
    adata,
    samples_per_epoch=samples_per_epoch,
    n_pairs=n_pairs,
    n_negative=n_negative,
    seed=seed,
    trans_fraction=trans_fraction,
    cis_window=cis_window,
    same_chr_negative_prob=same_chr_negative_prob,
    # cis_distance_func="exp",
    # cis_distance_param=5e5
)

loader = DataLoader(
    dataset,
    batch_size=batch_size,
    collate_fn=peak2vec_collate,
    num_workers=0,
    pin_memory=True
)

# %%
#model = Peak2Vec(adata.n_vars, embedding_dim=embedding_dim).to(device)
#optimizer = torch.optim.Adam(model.parameters(), lr=2e-3)

# %%
num_epochs = 200

for epoch in range(1, num_epochs + 1):
    model.train()

    running = 0.0
    running_pos = 0.0
    running_neg = 0.0
    #dataset.set_epoch(epoch)
    for step, (peaks, peak_pairs, negatives) in enumerate(loader, 1):
        peaks = peaks.to(device, non_blocking=True)
        peak_pairs = peak_pairs.to(device, non_blocking=True)
        negatives = negatives.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)
        loss, stats = model(peaks, peak_pairs, negatives)
        loss.backward()
        
        optimizer.step()

        running += float(loss.detach().cpu())
        running_pos += float(stats["pos_loss_mean"].cpu())
        running_neg += float(stats["neg_loss_mean"].cpu())

        #print(f"Epoch {epoch} | Step {step:03d} | Loss: {running / step:.4f} | Pos Loss: {stats['pos_loss_mean']:.4f} | Neg Loss: {stats['neg_loss_mean']:.4f} | Pos Score: {stats['pos_score_mean']:.4f} | Neg Score: {stats['neg_score_mean']:.4f}")
    
    # Log epoch stats
    stats["running_loss"] = running / step
    stats["pos_loss_mean"] = running_pos / step
    stats["neg_loss_mean"] = running_neg / step
    history.append(stats)
    print(f"Epoch {epoch} | Step {step:03d} | Loss: {running / step:.6f} | Pos Loss: {stats['pos_loss_mean']:.6f} | Neg Loss: {stats['neg_loss_mean']:.6f} | Pos Score: {stats['pos_score_mean']:.6f} | Neg Score: {stats['neg_score_mean']:.6f}")
# Out:
# Epoch 1 | Step 040 | Loss: 1.412229 | Pos Loss: 0.007710 | Neg Loss: 1.404519 | Pos Score: 6.670088 | Neg Score: -4.654418
# Epoch 2 | Step 040 | Loss: 1.402787 | Pos Loss: 0.007655 | Neg Loss: 1.395132 | Pos Score: 6.658849 | Neg Score: -4.756676
# Epoch 3 | Step 040 | Loss: 1.399202 | Pos Loss: 0.007672 | Neg Loss: 1.391530 | Pos Score: 6.634899 | Neg Score: -4.710632
# Epoch 4 | Step 040 | Loss: 1.382613 | Pos Loss: 0.007626 | Neg Loss: 1.374987 | Pos Score: 6.602074 | Neg Score: -5.232674
# Epoch 5 | Step 040 | Loss: 1.426102 | Pos Loss: 0.007591 | Neg Loss: 1.418512 | Pos Score: 6.549298 | Neg Score: -4.914051
# Epoch 6 | Step 040 | Loss: 1.409685 | Pos Loss: 0.007549 | Neg Loss: 1.402137 | Pos Score: 6.606463 | Neg Score: -4.807586
# Epoch 7 | Step 040 | Loss: 1.394037 | Pos Loss: 0.007546 | Neg Loss: 1.386491 | Pos Score: 6.618412 | Neg Score: -4.928411
# Epoch 8 | Step 040 | Loss: 1.408773 | Pos Loss: 0.007532 | Neg Loss: 1.401242 | Pos Score: 6.591296 | Neg Score: -4.850355
# Epoch 9 | Step 040 | Loss: 1.401541 | Pos Loss: 0.007490 | Neg Loss: 1.394051 | Pos Score: 6.614053 | Neg Score: -4.788980
# Epoch 10 | Step 040 | Loss: 1.399116 | Pos Loss: 0.007439 | Neg Loss: 1.391677 | Pos Score: 6.672585 | Neg Score: -4.953194
# Epoch 11 | Step 040 | Loss: 1.403517 | Pos Loss: 0.007393 | Neg Loss: 1.396124 | Pos Score: 6.718762 | Neg Score: -5.027759
# Epoch 12 | Step 040 | Loss: 1.393599 | Pos Loss: 0.007347 | Neg Loss: 1.386252 | Pos Score: 6.715491 | Neg Score: -4.768317
# Epoch 13 | Step 040 | Loss: 1.393617 | Pos Loss: 0.007341 | Neg Loss: 1.386276 | Pos Score: 6.739855 | Neg Score: -4.724628
# Epoch 14 | Step 040 | Loss: 1.390871 | Pos Loss: 0.007329 | Neg Loss: 1.383542 | Pos Score: 6.750568 | Neg Score: -4.793544
# Epoch 15 | Step 040 | Loss: 1.389195 | Pos Loss: 0.007310 | Neg Loss: 1.381885 | Pos Score: 6.741507 | Neg Score: -4.910598
# Epoch 16 | Step 040 | Loss: 1.399813 | Pos Loss: 0.007333 | Neg Loss: 1.392480 | Pos Score: 6.667233 | Neg Score: -5.098268
# Epoch 17 | Step 040 | Loss: 1.392948 | Pos Loss: 0.007312 | Neg Loss: 1.385636 | Pos Score: 6.682556 | Neg Score: -5.070461
# Epoch 18 | Step 040 | Loss: 1.376131 | Pos Loss: 0.007261 | Neg Loss: 1.368871 | Pos Score: 6.649433 | Neg Score: -5.001794
# Epoch 19 | Step 040 | Loss: 1.381391 | Pos Loss: 0.007234 | Neg Loss: 1.374157 | Pos Score: 6.594114 | Neg Score: -5.120819
# Epoch 20 | Step 040 | Loss: 1.395903 | Pos Loss: 0.007197 | Neg Loss: 1.388707 | Pos Score: 6.599633 | Neg Score: -5.011603
# Epoch 21 | Step 040 | Loss: 1.394419 | Pos Loss: 0.007221 | Neg Loss: 1.387198 | Pos Score: 6.528182 | Neg Score: -4.809016
# Epoch 22 | Step 040 | Loss: 1.368682 | Pos Loss: 0.007186 | Neg Loss: 1.361496 | Pos Score: 6.542904 | Neg Score: -5.302986
# Epoch 23 | Step 040 | Loss: 1.370268 | Pos Loss: 0.007160 | Neg Loss: 1.363107 | Pos Score: 6.552386 | Neg Score: -5.244929
# Epoch 24 | Step 040 | Loss: 1.362033 | Pos Loss: 0.007160 | Neg Loss: 1.354873 | Pos Score: 6.577316 | Neg Score: -4.973587
# Epoch 25 | Step 040 | Loss: 1.381896 | Pos Loss: 0.007113 | Neg Loss: 1.374783 | Pos Score: 6.564053 | Neg Score: -5.030900
# Epoch 26 | Step 040 | Loss: 1.380132 | Pos Loss: 0.007082 | Neg Loss: 1.373050 | Pos Score: 6.617302 | Neg Score: -4.814349
# Epoch 27 | Step 040 | Loss: 1.364198 | Pos Loss: 0.007083 | Neg Loss: 1.357115 | Pos Score: 6.663329 | Neg Score: -4.835536
# Epoch 28 | Step 040 | Loss: 1.390467 | Pos Loss: 0.007095 | Neg Loss: 1.383372 | Pos Score: 6.620143 | Neg Score: -4.655911
# Epoch 29 | Step 040 | Loss: 1.349721 | Pos Loss: 0.007065 | Neg Loss: 1.342656 | Pos Score: 6.653088 | Neg Score: -4.942656
# Epoch 30 | Step 040 | Loss: 1.358134 | Pos Loss: 0.007007 | Neg Loss: 1.351128 | Pos Score: 6.629257 | Neg Score: -5.058929
# Epoch 31 | Step 040 | Loss: 1.361777 | Pos Loss: 0.006981 | Neg Loss: 1.354796 | Pos Score: 6.664227 | Neg Score: -5.004632
# Epoch 32 | Step 040 | Loss: 1.360458 | Pos Loss: 0.006977 | Neg Loss: 1.353481 | Pos Score: 6.671205 | Neg Score: -4.963089
# Epoch 33 | Step 040 | Loss: 1.372269 | Pos Loss: 0.007008 | Neg Loss: 1.365262 | Pos Score: 6.585728 | Neg Score: -5.191784
# Epoch 34 | Step 040 | Loss: 1.380880 | Pos Loss: 0.006910 | Neg Loss: 1.373970 | Pos Score: 6.607616 | Neg Score: -4.855052
# Epoch 35 | Step 040 | Loss: 1.371988 | Pos Loss: 0.006860 | Neg Loss: 1.365129 | Pos Score: 6.686316 | Neg Score: -5.071887
# Epoch 36 | Step 040 | Loss: 1.370006 | Pos Loss: 0.006866 | Neg Loss: 1.363140 | Pos Score: 6.695404 | Neg Score: -5.036699
# Epoch 37 | Step 040 | Loss: 1.352027 | Pos Loss: 0.006823 | Neg Loss: 1.345205 | Pos Score: 6.676098 | Neg Score: -5.151890
# Epoch 38 | Step 040 | Loss: 1.343309 | Pos Loss: 0.006820 | Neg Loss: 1.336489 | Pos Score: 6.627008 | Neg Score: -4.935215
# Epoch 39 | Step 040 | Loss: 1.368108 | Pos Loss: 0.006814 | Neg Loss: 1.361294 | Pos Score: 6.522208 | Neg Score: -4.865189
# Epoch 40 | Step 040 | Loss: 1.356160 | Pos Loss: 0.006822 | Neg Loss: 1.349338 | Pos Score: 6.580738 | Neg Score: -5.058675
# Epoch 41 | Step 040 | Loss: 1.362238 | Pos Loss: 0.006788 | Neg Loss: 1.355450 | Pos Score: 6.601230 | Neg Score: -4.843055
# Epoch 42 | Step 040 | Loss: 1.360729 | Pos Loss: 0.006739 | Neg Loss: 1.353989 | Pos Score: 6.616202 | Neg Score: -4.935254
# Epoch 43 | Step 040 | Loss: 1.368138 | Pos Loss: 0.006743 | Neg Loss: 1.361395 | Pos Score: 6.662580 | Neg Score: -4.693427
# Epoch 44 | Step 040 | Loss: 1.353786 | Pos Loss: 0.006684 | Neg Loss: 1.347101 | Pos Score: 6.717258 | Neg Score: -4.821641
# Epoch 45 | Step 040 | Loss: 1.354204 | Pos Loss: 0.006684 | Neg Loss: 1.347520 | Pos Score: 6.737997 | Neg Score: -4.896671
# Epoch 46 | Step 040 | Loss: 1.338048 | Pos Loss: 0.006662 | Neg Loss: 1.331386 | Pos Score: 6.719221 | Neg Score: -4.873544
# Epoch 47 | Step 040 | Loss: 1.341545 | Pos Loss: 0.006645 | Neg Loss: 1.334900 | Pos Score: 6.677557 | Neg Score: -4.977307
# Epoch 48 | Step 040 | Loss: 1.336454 | Pos Loss: 0.006613 | Neg Loss: 1.329841 | Pos Score: 6.716608 | Neg Score: -5.147076
# Epoch 49 | Step 040 | Loss: 1.343911 | Pos Loss: 0.006590 | Neg Loss: 1.337322 | Pos Score: 6.713546 | Neg Score: -5.137371
# Epoch 50 | Step 040 | Loss: 1.320672 | Pos Loss: 0.006558 | Neg Loss: 1.314114 | Pos Score: 6.737494 | Neg Score: -5.178237
# Epoch 51 | Step 040 | Loss: 1.354244 | Pos Loss: 0.006567 | Neg Loss: 1.347677 | Pos Score: 6.741366 | Neg Score: -4.950910
# Epoch 52 | Step 040 | Loss: 1.355167 | Pos Loss: 0.006640 | Neg Loss: 1.348527 | Pos Score: 6.732431 | Neg Score: -5.213602
# Epoch 53 | Step 040 | Loss: 1.336465 | Pos Loss: 0.006545 | Neg Loss: 1.329920 | Pos Score: 6.746798 | Neg Score: -5.035545
# Epoch 54 | Step 040 | Loss: 1.334844 | Pos Loss: 0.006536 | Neg Loss: 1.328308 | Pos Score: 6.695504 | Neg Score: -5.127956
# Epoch 55 | Step 040 | Loss: 1.335708 | Pos Loss: 0.006537 | Neg Loss: 1.329171 | Pos Score: 6.702130 | Neg Score: -4.948566
# Epoch 56 | Step 040 | Loss: 1.340468 | Pos Loss: 0.006515 | Neg Loss: 1.333953 | Pos Score: 6.721608 | Neg Score: -5.152534
# Epoch 57 | Step 040 | Loss: 1.338495 | Pos Loss: 0.006497 | Neg Loss: 1.331998 | Pos Score: 6.758270 | Neg Score: -5.269161
# Epoch 58 | Step 040 | Loss: 1.350874 | Pos Loss: 0.006439 | Neg Loss: 1.344435 | Pos Score: 6.757076 | Neg Score: -5.179982
# Epoch 59 | Step 040 | Loss: 1.331381 | Pos Loss: 0.006428 | Neg Loss: 1.324953 | Pos Score: 6.802380 | Neg Score: -5.186216
# Epoch 60 | Step 040 | Loss: 1.326685 | Pos Loss: 0.006452 | Neg Loss: 1.320233 | Pos Score: 6.776217 | Neg Score: -5.297416
# Epoch 61 | Step 040 | Loss: 1.337272 | Pos Loss: 0.006369 | Neg Loss: 1.330904 | Pos Score: 6.789431 | Neg Score: -5.145008
# Epoch 62 | Step 040 | Loss: 1.331967 | Pos Loss: 0.006345 | Neg Loss: 1.325622 | Pos Score: 6.840246 | Neg Score: -5.240511
# Epoch 63 | Step 040 | Loss: 1.324271 | Pos Loss: 0.006341 | Neg Loss: 1.317930 | Pos Score: 6.836962 | Neg Score: -5.033110
# Epoch 64 | Step 040 | Loss: 1.346724 | Pos Loss: 0.006324 | Neg Loss: 1.340400 | Pos Score: 6.857629 | Neg Score: -4.846839
# Epoch 65 | Step 040 | Loss: 1.343085 | Pos Loss: 0.006295 | Neg Loss: 1.336790 | Pos Score: 6.863955 | Neg Score: -4.973570
# Epoch 66 | Step 040 | Loss: 1.318614 | Pos Loss: 0.006290 | Neg Loss: 1.312325 | Pos Score: 6.805988 | Neg Score: -5.298703
# Epoch 67 | Step 040 | Loss: 1.320839 | Pos Loss: 0.006287 | Neg Loss: 1.314552 | Pos Score: 6.807065 | Neg Score: -5.104591
# Epoch 68 | Step 040 | Loss: 1.340062 | Pos Loss: 0.006290 | Neg Loss: 1.333772 | Pos Score: 6.767462 | Neg Score: -5.036329
# Epoch 69 | Step 040 | Loss: 1.317280 | Pos Loss: 0.006263 | Neg Loss: 1.311018 | Pos Score: 6.872345 | Neg Score: -5.047106
# Epoch 70 | Step 040 | Loss: 1.307505 | Pos Loss: 0.006266 | Neg Loss: 1.301239 | Pos Score: 6.864210 | Neg Score: -5.139017
# Epoch 71 | Step 040 | Loss: 1.321586 | Pos Loss: 0.006257 | Neg Loss: 1.315329 | Pos Score: 6.811708 | Neg Score: -5.158034
# Epoch 72 | Step 040 | Loss: 1.327504 | Pos Loss: 0.006249 | Neg Loss: 1.321255 | Pos Score: 6.815580 | Neg Score: -5.220079
# Epoch 73 | Step 040 | Loss: 1.326844 | Pos Loss: 0.006225 | Neg Loss: 1.320619 | Pos Score: 6.833421 | Neg Score: -5.046193
# Epoch 74 | Step 040 | Loss: 1.318049 | Pos Loss: 0.006207 | Neg Loss: 1.311842 | Pos Score: 6.875928 | Neg Score: -5.221678
# Epoch 75 | Step 040 | Loss: 1.330236 | Pos Loss: 0.006199 | Neg Loss: 1.324037 | Pos Score: 6.846196 | Neg Score: -5.063483
# Epoch 76 | Step 040 | Loss: 1.318470 | Pos Loss: 0.006184 | Neg Loss: 1.312286 | Pos Score: 6.866176 | Neg Score: -5.180618
# Epoch 77 | Step 040 | Loss: 1.300632 | Pos Loss: 0.006180 | Neg Loss: 1.294452 | Pos Score: 6.877450 | Neg Score: -5.268543
# Epoch 78 | Step 040 | Loss: 1.315042 | Pos Loss: 0.006142 | Neg Loss: 1.308900 | Pos Score: 6.836250 | Neg Score: -5.155225
# Epoch 79 | Step 040 | Loss: 1.314569 | Pos Loss: 0.006144 | Neg Loss: 1.308425 | Pos Score: 6.882441 | Neg Score: -5.110491
# Epoch 80 | Step 040 | Loss: 1.321719 | Pos Loss: 0.006127 | Neg Loss: 1.315592 | Pos Score: 6.836672 | Neg Score: -4.934593
# Epoch 81 | Step 040 | Loss: 1.306770 | Pos Loss: 0.006151 | Neg Loss: 1.300619 | Pos Score: 6.909838 | Neg Score: -5.220541
# Epoch 82 | Step 040 | Loss: 1.307555 | Pos Loss: 0.006137 | Neg Loss: 1.301418 | Pos Score: 6.878165 | Neg Score: -5.177292
# Epoch 83 | Step 040 | Loss: 1.313508 | Pos Loss: 0.006128 | Neg Loss: 1.307380 | Pos Score: 6.869113 | Neg Score: -5.300550
# Epoch 84 | Step 040 | Loss: 1.321285 | Pos Loss: 0.006115 | Neg Loss: 1.315170 | Pos Score: 6.891348 | Neg Score: -4.899061
# Epoch 85 | Step 040 | Loss: 1.310570 | Pos Loss: 0.006097 | Neg Loss: 1.304472 | Pos Score: 6.934875 | Neg Score: -5.209025
# Epoch 86 | Step 040 | Loss: 1.313400 | Pos Loss: 0.006136 | Neg Loss: 1.307263 | Pos Score: 6.893873 | Neg Score: -4.935848
# Epoch 87 | Step 040 | Loss: 1.322103 | Pos Loss: 0.006097 | Neg Loss: 1.316007 | Pos Score: 6.948615 | Neg Score: -4.854671
# Epoch 88 | Step 040 | Loss: 1.308422 | Pos Loss: 0.006134 | Neg Loss: 1.302288 | Pos Score: 6.897923 | Neg Score: -5.162285
# Epoch 89 | Step 040 | Loss: 1.306257 | Pos Loss: 0.006093 | Neg Loss: 1.300164 | Pos Score: 6.813914 | Neg Score: -5.025319
# Epoch 90 | Step 040 | Loss: 1.298352 | Pos Loss: 0.006035 | Neg Loss: 1.292317 | Pos Score: 6.813698 | Neg Score: -5.069685
# Epoch 91 | Step 040 | Loss: 1.303929 | Pos Loss: 0.006015 | Neg Loss: 1.297915 | Pos Score: 6.835096 | Neg Score: -5.277500
# Epoch 92 | Step 040 | Loss: 1.287303 | Pos Loss: 0.006055 | Neg Loss: 1.281248 | Pos Score: 6.814906 | Neg Score: -5.247352
# Epoch 93 | Step 040 | Loss: 1.295947 | Pos Loss: 0.006021 | Neg Loss: 1.289926 | Pos Score: 6.820506 | Neg Score: -5.296055
# Epoch 94 | Step 040 | Loss: 1.292831 | Pos Loss: 0.005988 | Neg Loss: 1.286842 | Pos Score: 6.849431 | Neg Score: -5.271359
# Epoch 95 | Step 040 | Loss: 1.295251 | Pos Loss: 0.005975 | Neg Loss: 1.289276 | Pos Score: 6.857605 | Neg Score: -5.319204
# Epoch 96 | Step 040 | Loss: 1.305174 | Pos Loss: 0.006061 | Neg Loss: 1.299114 | Pos Score: 6.897346 | Neg Score: -5.144176
# Epoch 97 | Step 040 | Loss: 1.301360 | Pos Loss: 0.005959 | Neg Loss: 1.295401 | Pos Score: 6.884775 | Neg Score: -5.233842
# Epoch 98 | Step 040 | Loss: 1.292583 | Pos Loss: 0.005953 | Neg Loss: 1.286630 | Pos Score: 6.918718 | Neg Score: -5.324290
# Epoch 99 | Step 040 | Loss: 1.301214 | Pos Loss: 0.005915 | Neg Loss: 1.295299 | Pos Score: 6.904124 | Neg Score: -5.258633
# Epoch 100 | Step 040 | Loss: 1.288594 | Pos Loss: 0.005898 | Neg Loss: 1.282696 | Pos Score: 6.899349 | Neg Score: -5.119401
# Epoch 101 | Step 040 | Loss: 1.285309 | Pos Loss: 0.005892 | Neg Loss: 1.279417 | Pos Score: 6.906891 | Neg Score: -5.327754
# Epoch 102 | Step 040 | Loss: 1.296972 | Pos Loss: 0.005875 | Neg Loss: 1.291097 | Pos Score: 6.944764 | Neg Score: -4.998647
# Epoch 103 | Step 040 | Loss: 1.296634 | Pos Loss: 0.005847 | Neg Loss: 1.290786 | Pos Score: 6.959677 | Neg Score: -5.405019
# Epoch 104 | Step 040 | Loss: 1.312569 | Pos Loss: 0.005829 | Neg Loss: 1.306741 | Pos Score: 6.915700 | Neg Score: -5.257377
# Epoch 105 | Step 040 | Loss: 1.290871 | Pos Loss: 0.005847 | Neg Loss: 1.285025 | Pos Score: 6.887386 | Neg Score: -5.153593
# Epoch 106 | Step 040 | Loss: 1.296168 | Pos Loss: 0.005810 | Neg Loss: 1.290359 | Pos Score: 6.937713 | Neg Score: -5.259179
# Epoch 107 | Step 040 | Loss: 1.293447 | Pos Loss: 0.005792 | Neg Loss: 1.287655 | Pos Score: 6.961575 | Neg Score: -5.139022
# Epoch 108 | Step 040 | Loss: 1.292733 | Pos Loss: 0.005824 | Neg Loss: 1.286908 | Pos Score: 6.925825 | Neg Score: -5.193858
# Epoch 109 | Step 040 | Loss: 1.304667 | Pos Loss: 0.005776 | Neg Loss: 1.298890 | Pos Score: 6.889560 | Neg Score: -5.187000
# Epoch 110 | Step 040 | Loss: 1.296973 | Pos Loss: 0.005759 | Neg Loss: 1.291214 | Pos Score: 6.820691 | Neg Score: -5.155239
# Epoch 111 | Step 040 | Loss: 1.291526 | Pos Loss: 0.005750 | Neg Loss: 1.285776 | Pos Score: 6.838223 | Neg Score: -5.099945
# Epoch 112 | Step 040 | Loss: 1.297795 | Pos Loss: 0.005740 | Neg Loss: 1.292055 | Pos Score: 6.834656 | Neg Score: -5.208145
# Epoch 113 | Step 040 | Loss: 1.290103 | Pos Loss: 0.005817 | Neg Loss: 1.284286 | Pos Score: 6.851667 | Neg Score: -5.378002
# Epoch 114 | Step 040 | Loss: 1.284690 | Pos Loss: 0.005765 | Neg Loss: 1.278926 | Pos Score: 6.764824 | Neg Score: -5.502802
# Epoch 115 | Step 040 | Loss: 1.281420 | Pos Loss: 0.005711 | Neg Loss: 1.275709 | Pos Score: 6.675776 | Neg Score: -5.445356
# Epoch 116 | Step 040 | Loss: 1.289719 | Pos Loss: 0.005727 | Neg Loss: 1.283992 | Pos Score: 6.732902 | Neg Score: -5.350003
# Epoch 117 | Step 040 | Loss: 1.294853 | Pos Loss: 0.005695 | Neg Loss: 1.289158 | Pos Score: 6.832814 | Neg Score: -5.113515
# Epoch 118 | Step 040 | Loss: 1.278630 | Pos Loss: 0.005707 | Neg Loss: 1.272924 | Pos Score: 6.889875 | Neg Score: -5.222448
# Epoch 119 | Step 040 | Loss: 1.277630 | Pos Loss: 0.005752 | Neg Loss: 1.271878 | Pos Score: 6.865559 | Neg Score: -5.507318
# Epoch 120 | Step 040 | Loss: 1.287034 | Pos Loss: 0.005799 | Neg Loss: 1.281235 | Pos Score: 6.923574 | Neg Score: -5.367495
# Epoch 121 | Step 040 | Loss: 1.274368 | Pos Loss: 0.005661 | Neg Loss: 1.268707 | Pos Score: 6.962072 | Neg Score: -5.422958
# Epoch 122 | Step 040 | Loss: 1.283436 | Pos Loss: 0.005645 | Neg Loss: 1.277790 | Pos Score: 6.978012 | Neg Score: -5.089545
# Epoch 123 | Step 040 | Loss: 1.281583 | Pos Loss: 0.005640 | Neg Loss: 1.275943 | Pos Score: 7.002684 | Neg Score: -5.059944
# Epoch 124 | Step 040 | Loss: 1.291649 | Pos Loss: 0.005655 | Neg Loss: 1.285994 | Pos Score: 7.036767 | Neg Score: -5.189144
# Epoch 125 | Step 040 | Loss: 1.282540 | Pos Loss: 0.005627 | Neg Loss: 1.276913 | Pos Score: 7.075713 | Neg Score: -5.117054
# Epoch 126 | Step 040 | Loss: 1.284716 | Pos Loss: 0.005578 | Neg Loss: 1.279138 | Pos Score: 7.063770 | Neg Score: -5.222467
# Epoch 127 | Step 040 | Loss: 1.273561 | Pos Loss: 0.005599 | Neg Loss: 1.267962 | Pos Score: 7.080438 | Neg Score: -5.501266
# Epoch 128 | Step 040 | Loss: 1.285295 | Pos Loss: 0.005542 | Neg Loss: 1.279753 | Pos Score: 7.072130 | Neg Score: -5.161952
# Epoch 129 | Step 040 | Loss: 1.267181 | Pos Loss: 0.005588 | Neg Loss: 1.261593 | Pos Score: 7.029361 | Neg Score: -5.456426
# Epoch 130 | Step 040 | Loss: 1.265854 | Pos Loss: 0.005556 | Neg Loss: 1.260298 | Pos Score: 7.024669 | Neg Score: -5.226306
# Epoch 131 | Step 040 | Loss: 1.291825 | Pos Loss: 0.005539 | Neg Loss: 1.286286 | Pos Score: 7.054323 | Neg Score: -5.417547
# Epoch 132 | Step 040 | Loss: 1.271913 | Pos Loss: 0.005544 | Neg Loss: 1.266369 | Pos Score: 7.111990 | Neg Score: -5.469820
# Epoch 133 | Step 040 | Loss: 1.268134 | Pos Loss: 0.005592 | Neg Loss: 1.262542 | Pos Score: 7.088728 | Neg Score: -5.460308
# Epoch 134 | Step 040 | Loss: 1.286067 | Pos Loss: 0.005561 | Neg Loss: 1.280506 | Pos Score: 7.088897 | Neg Score: -5.434791
# Epoch 135 | Step 040 | Loss: 1.277522 | Pos Loss: 0.005536 | Neg Loss: 1.271986 | Pos Score: 7.041183 | Neg Score: -5.361152
# Epoch 136 | Step 040 | Loss: 1.265666 | Pos Loss: 0.005576 | Neg Loss: 1.260090 | Pos Score: 7.040143 | Neg Score: -5.385189
# Epoch 137 | Step 040 | Loss: 1.266492 | Pos Loss: 0.005537 | Neg Loss: 1.260954 | Pos Score: 7.074541 | Neg Score: -5.370603
# Epoch 138 | Step 040 | Loss: 1.265023 | Pos Loss: 0.005531 | Neg Loss: 1.259492 | Pos Score: 7.100703 | Neg Score: -5.483193
# Epoch 139 | Step 040 | Loss: 1.287045 | Pos Loss: 0.005510 | Neg Loss: 1.281535 | Pos Score: 7.089937 | Neg Score: -5.231788
# Epoch 140 | Step 040 | Loss: 1.275498 | Pos Loss: 0.005526 | Neg Loss: 1.269972 | Pos Score: 7.137180 | Neg Score: -5.289240
# Epoch 141 | Step 040 | Loss: 1.280151 | Pos Loss: 0.005510 | Neg Loss: 1.274641 | Pos Score: 7.127579 | Neg Score: -5.059881
# Epoch 142 | Step 040 | Loss: 1.262111 | Pos Loss: 0.005465 | Neg Loss: 1.256646 | Pos Score: 7.163883 | Neg Score: -5.226214
# Epoch 143 | Step 040 | Loss: 1.276239 | Pos Loss: 0.005498 | Neg Loss: 1.270741 | Pos Score: 7.143290 | Neg Score: -5.254369
# Epoch 144 | Step 040 | Loss: 1.275034 | Pos Loss: 0.005439 | Neg Loss: 1.269595 | Pos Score: 7.184609 | Neg Score: -5.236842
# Epoch 145 | Step 040 | Loss: 1.272709 | Pos Loss: 0.005429 | Neg Loss: 1.267280 | Pos Score: 7.136003 | Neg Score: -5.358963
# Epoch 146 | Step 040 | Loss: 1.254688 | Pos Loss: 0.005418 | Neg Loss: 1.249270 | Pos Score: 7.171112 | Neg Score: -5.541186
# Epoch 147 | Step 040 | Loss: 1.254108 | Pos Loss: 0.005438 | Neg Loss: 1.248670 | Pos Score: 7.172708 | Neg Score: -5.412335
# Epoch 148 | Step 040 | Loss: 1.268990 | Pos Loss: 0.005432 | Neg Loss: 1.263558 | Pos Score: 7.164517 | Neg Score: -5.352812
# Epoch 149 | Step 040 | Loss: 1.255016 | Pos Loss: 0.005413 | Neg Loss: 1.249602 | Pos Score: 7.100051 | Neg Score: -5.545849
# Epoch 150 | Step 040 | Loss: 1.249379 | Pos Loss: 0.005398 | Neg Loss: 1.243981 | Pos Score: 7.123204 | Neg Score: -5.596595
# Epoch 151 | Step 040 | Loss: 1.265199 | Pos Loss: 0.005407 | Neg Loss: 1.259792 | Pos Score: 7.135434 | Neg Score: -5.492424
# Epoch 152 | Step 040 | Loss: 1.274215 | Pos Loss: 0.005422 | Neg Loss: 1.268793 | Pos Score: 7.138502 | Neg Score: -5.504770
# Epoch 153 | Step 040 | Loss: 1.260702 | Pos Loss: 0.005381 | Neg Loss: 1.255321 | Pos Score: 7.198943 | Neg Score: -5.608684
# Epoch 154 | Step 040 | Loss: 1.253812 | Pos Loss: 0.005419 | Neg Loss: 1.248394 | Pos Score: 7.082350 | Neg Score: -5.661430
# Epoch 155 | Step 040 | Loss: 1.273746 | Pos Loss: 0.005422 | Neg Loss: 1.268324 | Pos Score: 7.077205 | Neg Score: -5.448624
# Epoch 156 | Step 040 | Loss: 1.272565 | Pos Loss: 0.005384 | Neg Loss: 1.267181 | Pos Score: 7.132246 | Neg Score: -5.352094
# Epoch 157 | Step 040 | Loss: 1.254458 | Pos Loss: 0.005430 | Neg Loss: 1.249028 | Pos Score: 7.112677 | Neg Score: -5.406778
# Epoch 158 | Step 040 | Loss: 1.261249 | Pos Loss: 0.005400 | Neg Loss: 1.255849 | Pos Score: 7.144952 | Neg Score: -5.383005
# Epoch 159 | Step 040 | Loss: 1.265875 | Pos Loss: 0.005433 | Neg Loss: 1.260442 | Pos Score: 7.093033 | Neg Score: -5.505622
# Epoch 160 | Step 040 | Loss: 1.261938 | Pos Loss: 0.005387 | Neg Loss: 1.256551 | Pos Score: 7.137801 | Neg Score: -5.321880
# Epoch 161 | Step 040 | Loss: 1.265513 | Pos Loss: 0.005344 | Neg Loss: 1.260169 | Pos Score: 7.092338 | Neg Score: -5.301379
# Epoch 162 | Step 040 | Loss: 1.261241 | Pos Loss: 0.005360 | Neg Loss: 1.255881 | Pos Score: 7.083165 | Neg Score: -5.409233
# Epoch 163 | Step 040 | Loss: 1.250855 | Pos Loss: 0.005345 | Neg Loss: 1.245510 | Pos Score: 7.137220 | Neg Score: -5.378658
# Epoch 164 | Step 040 | Loss: 1.250612 | Pos Loss: 0.005380 | Neg Loss: 1.245233 | Pos Score: 7.110433 | Neg Score: -5.262348
# Epoch 165 | Step 040 | Loss: 1.260067 | Pos Loss: 0.005346 | Neg Loss: 1.254720 | Pos Score: 7.008997 | Neg Score: -5.509160
# Epoch 166 | Step 040 | Loss: 1.255253 | Pos Loss: 0.005323 | Neg Loss: 1.249930 | Pos Score: 7.070195 | Neg Score: -5.448818
# Epoch 167 | Step 040 | Loss: 1.252434 | Pos Loss: 0.005426 | Neg Loss: 1.247007 | Pos Score: 7.049212 | Neg Score: -5.567579
# Epoch 168 | Step 040 | Loss: 1.232358 | Pos Loss: 0.005352 | Neg Loss: 1.227006 | Pos Score: 7.068114 | Neg Score: -5.340888
# Epoch 169 | Step 040 | Loss: 1.254988 | Pos Loss: 0.005314 | Neg Loss: 1.249675 | Pos Score: 7.098965 | Neg Score: -5.622582
# Epoch 170 | Step 040 | Loss: 1.250108 | Pos Loss: 0.005456 | Neg Loss: 1.244652 | Pos Score: 7.130513 | Neg Score: -5.352509
# Epoch 171 | Step 040 | Loss: 1.231824 | Pos Loss: 0.005317 | Neg Loss: 1.226507 | Pos Score: 7.090184 | Neg Score: -5.664570
# Epoch 172 | Step 040 | Loss: 1.244502 | Pos Loss: 0.005282 | Neg Loss: 1.239220 | Pos Score: 6.984476 | Neg Score: -5.484293
# Epoch 173 | Step 040 | Loss: 1.248595 | Pos Loss: 0.005247 | Neg Loss: 1.243348 | Pos Score: 6.992640 | Neg Score: -5.732083
# Epoch 174 | Step 040 | Loss: 1.263230 | Pos Loss: 0.005253 | Neg Loss: 1.257977 | Pos Score: 7.015930 | Neg Score: -5.586067
# Epoch 175 | Step 040 | Loss: 1.251380 | Pos Loss: 0.005251 | Neg Loss: 1.246130 | Pos Score: 7.137100 | Neg Score: -5.324705
# Epoch 176 | Step 040 | Loss: 1.261702 | Pos Loss: 0.005223 | Neg Loss: 1.256478 | Pos Score: 7.116301 | Neg Score: -5.347994
# Epoch 177 | Step 040 | Loss: 1.253950 | Pos Loss: 0.005241 | Neg Loss: 1.248709 | Pos Score: 7.047652 | Neg Score: -5.390694
# Epoch 178 | Step 040 | Loss: 1.256610 | Pos Loss: 0.005220 | Neg Loss: 1.251390 | Pos Score: 7.011458 | Neg Score: -5.535766
# Epoch 179 | Step 040 | Loss: 1.241957 | Pos Loss: 0.005237 | Neg Loss: 1.236720 | Pos Score: 6.899105 | Neg Score: -5.568352
# Epoch 180 | Step 040 | Loss: 1.266016 | Pos Loss: 0.005283 | Neg Loss: 1.260733 | Pos Score: 6.919002 | Neg Score: -5.711099
# Epoch 181 | Step 040 | Loss: 1.269439 | Pos Loss: 0.005246 | Neg Loss: 1.264193 | Pos Score: 6.887566 | Neg Score: -5.359220
# Epoch 182 | Step 040 | Loss: 1.236383 | Pos Loss: 0.005243 | Neg Loss: 1.231140 | Pos Score: 6.931311 | Neg Score: -5.774135
# Epoch 183 | Step 040 | Loss: 1.234861 | Pos Loss: 0.005249 | Neg Loss: 1.229612 | Pos Score: 6.890040 | Neg Score: -5.763365
# Epoch 184 | Step 040 | Loss: 1.235008 | Pos Loss: 0.005231 | Neg Loss: 1.229777 | Pos Score: 6.945244 | Neg Score: -5.802793
# Epoch 185 | Step 040 | Loss: 1.247015 | Pos Loss: 0.005231 | Neg Loss: 1.241784 | Pos Score: 6.884939 | Neg Score: -5.679346
# Epoch 186 | Step 040 | Loss: 1.238697 | Pos Loss: 0.005184 | Neg Loss: 1.233513 | Pos Score: 6.906062 | Neg Score: -5.828824
# Epoch 187 | Step 040 | Loss: 1.256048 | Pos Loss: 0.005167 | Neg Loss: 1.250881 | Pos Score: 6.916834 | Neg Score: -5.400701
# Epoch 188 | Step 040 | Loss: 1.245962 | Pos Loss: 0.005236 | Neg Loss: 1.240725 | Pos Score: 6.989679 | Neg Score: -5.323739
# Epoch 189 | Step 040 | Loss: 1.248730 | Pos Loss: 0.005194 | Neg Loss: 1.243536 | Pos Score: 7.022843 | Neg Score: -5.396705
# Epoch 190 | Step 040 | Loss: 1.256165 | Pos Loss: 0.005199 | Neg Loss: 1.250966 | Pos Score: 7.071506 | Neg Score: -5.269653
# Epoch 191 | Step 040 | Loss: 1.253385 | Pos Loss: 0.005187 | Neg Loss: 1.248198 | Pos Score: 7.143810 | Neg Score: -5.459101
# Epoch 192 | Step 040 | Loss: 1.247288 | Pos Loss: 0.005185 | Neg Loss: 1.242103 | Pos Score: 7.160962 | Neg Score: -5.234178
# Epoch 193 | Step 040 | Loss: 1.229549 | Pos Loss: 0.005252 | Neg Loss: 1.224297 | Pos Score: 7.130350 | Neg Score: -5.500385
# Epoch 194 | Step 040 | Loss: 1.229542 | Pos Loss: 0.005161 | Neg Loss: 1.224381 | Pos Score: 7.114470 | Neg Score: -5.423227
# Epoch 195 | Step 040 | Loss: 1.239003 | Pos Loss: 0.005134 | Neg Loss: 1.233870 | Pos Score: 7.103519 | Neg Score: -5.400656
# Epoch 196 | Step 040 | Loss: 1.244866 | Pos Loss: 0.005125 | Neg Loss: 1.239741 | Pos Score: 7.147124 | Neg Score: -5.225626
# Epoch 197 | Step 040 | Loss: 1.241400 | Pos Loss: 0.005157 | Neg Loss: 1.236242 | Pos Score: 7.151489 | Neg Score: -5.315179
# Epoch 198 | Step 040 | Loss: 1.231537 | Pos Loss: 0.005108 | Neg Loss: 1.226430 | Pos Score: 7.151934 | Neg Score: -5.443996
# Epoch 199 | Step 040 | Loss: 1.227762 | Pos Loss: 0.005096 | Neg Loss: 1.222666 | Pos Score: 7.108087 | Neg Score: -5.466302
# Epoch 200 | Step 040 | Loss: 1.249699 | Pos Loss: 0.005149 | Neg Loss: 1.244550 | Pos Score: 7.097460 | Neg Score: -5.529714

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(12, 8))

loss = [h["running_loss"] for h in history]
pos_loss = [h["pos_loss_mean"] for h in history]
neg_loss = [h["neg_loss_mean"] for h in history]
poss_score = [h["pos_score_mean"].detach().cpu() for h in history]
neg_score = [h["neg_score_mean"].detach().cpu() for h in history]

ax1.plot(range(1, len(loss) + 1), loss, label="Total Loss")
ax2.plot(range(1, len(loss) + 1), pos_loss, label="Positive Loss")
ax3.plot(range(1, len(loss) + 1), neg_loss, label="Negative Loss")
ax4.plot(range(1, len(loss) + 1), poss_score, label="Positive Score")
ax5.plot(range(1, len(loss) + 1), neg_score, label="Negative Score")
ax6.axis("off")

ax1.set_title("Total Loss")
ax2.set_title("Positive Loss")
ax3.set_title("Negative Loss")
ax4.set_title("Positive Score")
ax5.set_title("Negative Score")
# Out:
# Text(0.5, 1.0, 'Negative Score')

# %%
emb = model.get_peak_embeddings(normalize=False).numpy()
np.save(f"data/peak2vec_epoch_{embedding_dim}_{num_epochs + 200}_{trans_fraction}_{same_chr_negative_prob}.npy", emb)

emb = model.get_peak_embeddings(normalize=True).numpy()
np.save(f"data/peak2vec_epoch_norm_{embedding_dim}_{num_epochs + 200}_{trans_fraction}_{same_chr_negative_prob}.npy", emb)

# %%
torch.save(model, f'data/peak2vec_model_{embedding_dim}_{num_epochs + 200}_{trans_fraction}_{same_chr_negative_prob}.pth')

# %% [markdown]
# ## Visualize

# %% [markdown]
# ### Peaks

# %%
# adata_peaks = adata.transpose().copy()
adata_peaks.obsm["peak2vec"] = emb
adata_peaks
# Out:
# AnnData object with n_obs × n_vars = 264916 × 10126
#     obs: 'Chromosome', 'Start', 'End', 'Width', 'cisTopic_nr_frag', 'cisTopic_log_nr_frag', 'cisTopic_nr_acc', 'cisTopic_log_nr_acc', 'n_cells_per_feature', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'leiden'
#     var: 'cisTopic_nr_frag', 'cisTopic_log_nr_frag', 'cisTopic_nr_acc', 'cisTopic_log_nr_acc', 'sample_id', 'barcode_rank', 'total_fragments_count', 'log10_total_fragments_count', 'unique_fragments_count', 'log10_unique_fragments_count', 'total_fragments_in_peaks_count', 'log10_total_fragments_in_peaks_count', 'unique_fragments_in_peaks_count', 'log10_unique_fragments_in_peaks_count', 'fraction_of_fragments_in_peaks', 'duplication_count', 'duplication_ratio', 'nucleosome_signal', 'tss_enrichment', 'pdf_values_for_tss_enrichment', 'pdf_values_for_fraction_of_fragments_in_peaks', 'pdf_values_for_duplication_ratio', 'barcode', 'n_features_per_cell', 'total_fragment_counts', 'leiden'
#     uns: 'Chromosome_colors', 'leiden', 'leiden_colors', 'lsi', 'neighbors', 'umap'
#     obsm: 'LSI', 'X_umap', 'peak2vec', 'X_pca'
#     varm: 'X_lsi', 'X_umap'
#     layers: 'binary', 'counts'
#     obsp: 'connectivities', 'distances'
#     varp: 'connectivities', 'distances'

# %%
# Find neighbors
sc.pp.neighbors(adata_peaks, use_rep="peak2vec", n_neighbors=15, n_pcs=30, metric="cosine")

# Calculate clusters
# sc.tl.leiden(adata_peaks, flavor="igraph", n_iterations=2)

# Calculate UMAP
sc.tl.umap(adata_peaks, random_state=4)

# %%
sc.pl.umap(
    adata_peaks,
    color=["Chromosome"],
    ncols=1,
    save="peak2vec.png",
    # legend_loc="on data"
)
# Out:
# WARNING: saving figure to file figures\umappeak2vec.png

# %%
adata_peaks.obsm["X_pca"] = sc.pp.pca(emb, n_comps=50)
sc.pl.pca(adata_peaks, color=["Chromosome", "leiden"], ncols=1)

# %%
sc.pl.embedding(adata_peaks, basis="peak2vec", color=["Chromosome"])
